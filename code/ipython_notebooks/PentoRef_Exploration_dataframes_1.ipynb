# %% [markdown]
# # Explore with pandas dataframes

# %%
import sys
sys.path.append("../python/")
import pentoref.IO as IO

# %%
# Get the dataframes (can also use a database method instead)
CORPUS = "TAKE"  # Change this to one of [TAKE, TAKECV, PENTOCV] (as of 2020.05.22, PENTOCV takes 3-4 mins)
dfwords, dfutts, dfrefs, dfscenes, dfactions = IO.convert_subcorpus_raw_data_to_dataframes("../../../pentoref/{0}_PENTOREF".format(CORPUS))
# Out:
# Extracting TAKE
# TAKE
# extracting files in textgrid format
# 7 Transcription files read.
# /Users/julian/git/pentoref/TAKE_PENTOREF/derived_data/multimodal_data/scene_information/r1
# /Users/julian/git/pentoref/TAKE_PENTOREF/derived_data/multimodal_data/scene_information/r2
# /Users/julian/git/pentoref/TAKE_PENTOREF/derived_data/multimodal_data/scene_information/r3
# /Users/julian/git/pentoref/TAKE_PENTOREF/derived_data/multimodal_data/scene_information/r4
# /Users/julian/git/pentoref/TAKE_PENTOREF/derived_data/multimodal_data/scene_information/r5
# /Users/julian/git/pentoref/TAKE_PENTOREF/derived_data/multimodal_data/scene_information/r6
# /Users/julian/git/pentoref/TAKE_PENTOREF/derived_data/multimodal_data/scene_information/r7
# 1137 text files read. 1146 XML files parsed.
# Processing:
# r7...
# r1...
# r6...
# r3...
# r4...
# r5...
# r2...
# Done.
# 8605 words
# 2597 utterances
# 1035 references
# 15585 scenes
# no actions

# %%
dfwords
# Out:
#           word    starttime      endtime gameID  refID  uttID  position
# 0       rechts   139.444126   139.827419   r7_1      1      1         1
# 1        unten   139.827419   140.170477   r7_1      1      1         2
# 2         okay   143.593969   144.005850   r7_1      1      2         1
# 3        links   150.785674   151.034497   r7_2      2      3         1
# 4         oben   151.034497   151.232497   r7_2      2      3         2
# ...        ...          ...          ...    ...    ...    ...       ...
# 8600       ein  2941.726608  2942.035883  r2_80   1034    193         2
# 8601    grader  2942.035883  2942.736678  r2_80   1034    193         3
# 8602    Strich  2942.736678  2943.392483  r2_80   1034    193         4
# 8603  hellblau  2944.302921  2945.037000  r2_80   1034    193         5
# 8604        ja  2948.411011  2948.564671  r2_80   1034    194         1
#
# [8605 rows x 7 columns]

# %%
dfwords
# Out:
#            word   lemma  tag    gameID  uttID  position
# 0          okay    Okay  NNP  r7_1_1_s      2         1
# 1          dann    dann   RB  r7_1_1_s      4         1
# 2         nehme  nehmen   VB  r7_1_1_s      4         2
# 3           ich     ich  PRP  r7_1_1_s      4         3
# 4        einmal  einmal   RB  r7_1_1_s      4         4
# ...         ...     ...  ...       ...    ...       ...
# 32627     nicht   nicht   RB  r2_2_9_b  13897         4
# 32628     genug   genug   IN  r2_2_9_b  13897         5
# 32629    Drogen  Drogen   NN  r2_2_9_b  13897         6
# 32630       für     für   RB  r2_2_9_b  13897         7
# 32631  genommen  nehmen  VBN  r2_2_9_b  13897         8
#
# [32632 rows x 6 columns]

# %%
dfrefs
# Out:
#       refID  uttID    gameID                               text id   piece  \
# 0         1      4  r7_1_1_s                          das Blaue  I  target
# 1         2      6  r7_1_1_s                     das rote Kreuz  X  target
# 2         3     13  r7_1_2_s                         das Braune  Y  target
# 3         4     13  r7_1_2_s                              Grüne  W  target
# 4         5     13  r7_1_2_s                          das Pinke  P  target
# ...     ...    ...       ...                                ... ..     ...
# 2748   2749  13841  r2_2_8_s  die <v="orange">orangene</v> Eins  L  target
# 2749   2750  13861  r2_2_9_s                       das grüne $T  T  target
# 2750   2751  13861  r2_2_9_s                           das Plus  X  target
# 2751   2752  13861  r2_2_9_s                    die braune Eins  Y  target
# 2752   2753  13893  r2_2_9_b                                 $S  Z  target
#
#      location
# 0        None
# 1        None
# 2        None
# ...

# %%
dfscenes
# Out:
#         timestampID pieceID isLandmark isTarget position_global position_x  \
# 0       1000.070485       0       None     None    right center        411
# 1       1000.070485       1       None     None     left center         96
# 2       1000.070485       2       None     None    right center        475
# 3       1000.070485       3       None     None      center top        371
# 4       1000.070485       4       None     None     left center        189
# ...             ...     ...        ...      ...             ...        ...
# 462751   999.523810       7       None     None     left center        111
# 462752   999.523810       8       None     None    right center        470
# 462753   999.523810       9       None     None      center top        160
# 462754   999.523810      10       None     None      center top        229
# 462755   999.523810      11       None     None    right center        497
#
# ...

# %%
dfactions
# Out:
#        starttime   endtime hand           action piece    gameID
# 0        230.522   230.787   lh    move_to_piece     I  r7_1_2_b
# 1        230.787   230.892   lh       grab_piece     I  r7_1_2_b
# 2        230.892   231.950   lh  move_with_piece     I  r7_1_2_b
# 3        231.950   232.055   lh       drop_piece     I  r7_1_2_b
# 4        232.055   232.320   lh          retract     I  r7_1_2_b
# ...          ...       ...  ...              ...   ...       ...
# 12051   1799.358  1799.930   rh  move_with_piece     Z  r2_2_9_b
# 12052   1799.930  1801.025   rh     rotate_piece     Z  r2_2_9_b
# 12053   1801.025  1803.072   rh  move_with_piece     Z  r2_2_9_b
# 12054   1803.072  1803.310   rh       drop_piece     Z  r2_2_9_b
# 12055   1803.310  1804.215   rh          retract     Z  r2_2_9_b
#
# [12056 rows x 6 columns]
