# %% [markdown]
# # Explore with Sqlite databases

# %%
import sys
sys.path.append("../python/")
import pentoref.IO as IO
import sqlite3 as sqlite
from google_trans_new import google_translator

# %%
# Create databases if required
if False:   # make True if you need to create the databases from the derived data
    for corpus_name in ["TAKE", "TAKECV", "PENTOCV"]:
        data_dir = "../../../pentoref/{0}_PENTOREF".format(corpus_name)
        dfwords, dfutts, dfrefs, dfscenes, dfactions = IO.convert_subcorpus_raw_data_to_dataframes(data_dir)
        IO.write_corpus_to_database("{0}.db".format(corpus_name),
                                    corpus_name, dfwords, dfutts, dfrefs, dfscenes, dfactions)

# %%
# Connect to database
CORPUS = "PENTOCV"
db = sqlite.connect("{0}.db".format(CORPUS))
cursor = db.cursor()
# get the table column header names
print("utts", [x[1] for x in cursor.execute("PRAGMA table_info(utts)")])
print("words", [x[1] for x in cursor.execute("PRAGMA table_info(words)")])
print("refs", [x[1] for x in cursor.execute("PRAGMA table_info(refs)")])
print("scenes", [x[1] for x in cursor.execute("PRAGMA table_info(scenes)")])
print("actions", [x[1] for x in cursor.execute("PRAGMA table_info(actions)")])
# Out:
# utts ['gameID', 'uttID', 'starttime', 'endtime', 'utt', 'utt_clean', 'role', 'speaker']
# words ['gameID', 'uttID', 'position', 'word', 'lemma', 'tag']
# refs ['refID', 'gameID', 'uttID', 'text', 'id', 'piece', 'location']
# scenes ['timestampID', 'gameID', 'pieceID', 'position_global', 'position_x', 'position_y', 'shape', 'shape_distribution', 'shape_orientation', 'shape_skewness_horizontal', 'shape_skewness_vertical', 'shape_edges', 'colour', 'colour_distribution', 'colour_hsv', 'colour_rgb']
# actions ['gameID', 'starttime', 'endtime', 'hand', 'action', 'piece']

# %% [markdown]
# ## Get utterances from certain time periods in each experiment or for certain episodes

# %%
translator = google_translator()  

for row in db.execute("SELECT gameID, starttime, speaker, utt_clean FROM utts" + \
                   # " WHERE starttime >= 200 AND starttime <= 300" + \
                     ' WHERE gameID = "r1_1_1_b"' + \
                    " ORDER BY gameID, starttime"):
    print(row)
    line = row[3]
    print(line)
    if not line:
        continue
    translate_text = translator.translate(line,lang_src='de',lang_tgt='en') 
    print(translate_text)
# Out:
# ('r1_1_1_b', 185.719, 'A', '')
#
# ('r1_1_1_b', 194.232, 'B', 'leg das orange L mit der kurzen Seite nach rechts zeigend die lange Seite nach unten zu dir zu deinem Bauch hin')
# leg das orange L mit der kurzen Seite nach rechts zeigend die lange Seite nach unten zu dir zu deinem Bauch hin
# Leg the Orange L with the short side pointing to the right the long side down to you to your belly
# ('r1_1_1_b', 204.521, 'B', '')
#
# ('r1_1_1_b', 208.872, 'B', 'die kurze Seite nach rechts zeigend die lange Seite zu dir hin')
# die kurze Seite nach rechts zeigend die lange Seite zu dir hin
# The short side to the right pointing the long side to you
# ('r1_1_1_b', 211.999, 'B', '')
#
# ('r1_1_1_b', 213.9, 'B', 'genau')
# genau
# I agree
# ('r1_1_1_b', 214.356, 'B', '')
#
# ('r1_1_1_b', 215.105, 'B', 'das Kreuz nimmst du und setzt es oben auf die kurze Seite')
# das Kreuz nimmst du und setzt es oben auf die kurze Seite
# You take the cross and puts it up on the short side
# ('r1_1_1_b', 219.022, 'B', '')
#
# ('r1_1_1_b', 219.251, 'B', 'genau')
# genau
# I agree
# ('r1_1_1_b', 219.748, 'B', '')
#
# ('r1_1_1_b', 221.267, 'B', 'und jetzt haben wir noch')
# und jetzt haben wir noch
# And now we still have
# ('r1_1_1_b', 222.488, 'B', '')
#
# ('r1_1_1_b', 222.957, 'B', 'hm was war es')
# hm was war es
# Hm what was it
# ('r1_1_1_b', 224.421, 'B', '')
#
# ('r1_1_1_b', 225.005, 'B', 'moment d- das grüne T glaube ich ne? oder? hattest du noch')
# moment d- das grüne T glaube ich ne? oder? hattest du noch
# Moment D- The green t I think so? or? Did you still have
# ('r1_1_1_b', 227.04, 'A', 'ja')
# ja
# Yes
# ('r1_1_1_b', 227.37, 'A', '')
#
# ('r1_1_1_b', 228.117, 'B', '')
#
# ('r1_1_1_b', 228.488, 'B', 'das T legst du kippst du seitwärts nach links')
# das T legst du kippst du seitwärts nach links
# You put the t you tilt sideways to the left
# ('r1_1_1_b', 231.474, 'B', '')
#
# ('r1_1_1_b', 232.204, 'A', 'so ?')
# so ?
# So?
# ('r1_1_1_b', 232.309, 'B', 'und legst es da-')
# und legst es da-
# and put it
# ('r1_1_1_b', 233.16, 'B', 'nein')
# nein
# No
# ('r1_1_1_b', 233.6, 'B', 'nimm du legst es das T neunzig Grad ne n- das T stell mal aufrecht hin')
# nimm du legst es das T neunzig Grad ne n- das T stell mal aufrecht hin
# Take you the t ninety degree Ne n- the T say it upright
# ('r1_1_1_b', 241.893, 'B', '')
#
# ('r1_1_1_b', 242.949, 'B', 'dann kipp es um neunzig Grad')
# dann kipp es um neunzig Grad
# Then it tips ninety degrees
# ('r1_1_1_b', 244.86, 'B', '')
#
# ('r1_1_1_b', 245.41, 'B', 'und dann neunzig Grad nach links kippen')
# und dann neunzig Grad nach links kippen
# and then tilt ninety degrees to the left
# ('r1_1_1_b', 248.73, 'B', '')
#
# ('r1_1_1_b', 249.95, 'B', 'nach unten ziehen und in das zwischen')
# nach unten ziehen und in das zwischen
# pull down and in between
# ('r1_1_1_b', 252.61, 'B', 'noch eins weiter runter legen')
# noch eins weiter runter legen
# pause one more down
# ('r1_1_1_b', 254.38, 'B', 'es da hin genau')
# es da hin genau
# exactly
# ('r1_1_1_b', 255.456, 'B', '')
#
# ('r1_1_1_b', 256.243, 'B', 'okay')
# okay
# OK
# ('r1_1_1_b', 256.801, 'B', '')
#
# ('r1_1_1_b', 256.905, 'B', 'und jetzt das gelbe')
# und jetzt das gelbe
# and now the yellow
# ('r1_1_1_b', 258.434, 'B', '')
#
# ('r1_1_1_b', 259.119, 'B', 'die Brücke da oben drüber')
# die Brücke da oben drüber
# The bridge there above
# ('r1_1_1_b', 260.36, 'B', 'genau')
# genau
# I agree
# ('r1_1_1_b', 260.809, 'B', '')
#
# ('r1_1_1_b', 261.973, 'B', 'und das pinkfarbene Teil nimmst du und lest es da rein')
# und das pinkfarbene Teil nimmst du und lest es da rein
# and the pink part you take and read it in
# ('r1_1_1_b', 266.23, 'B', 'genau')
# genau
# I agree
# ('r1_1_1_b', 266.58, 'B', '')
#
# ('r1_1_1_b', 267.681, 'B', 'jetzt hast du ein geschlossenes Teil')
# jetzt hast du ein geschlossenes Teil
# Now you have a closed part
# ('r1_1_1_b', 269.239, 'B', '')
#
# ('r1_1_1_b', 271.715, 'B', 'und ich drücke jetzt reset')
# und ich drücke jetzt reset
# and I'm pressing RESET now

# %% [markdown]
# ## Get mutual information between words used in referring expressions and properties of the referent

# %%
from collections import Counter
from pentoref.IOutils import clean_utt

# %%
piece_counter = Counter()
word_counter = Counter()
word_piece_counter = Counter()
train_data = []
test_data = []

PAIR_NUM = "r10"

for row in db.execute("SELECT id, gameID, text, uttID FROM refs" + \
#for row in db.execute("SELECT shape, colour, orientation, gridPosition, gameID, pieceID FROM scenes" + \
                     " ORDER by gameID"):
    if False: 
        # TAKE
        isTarget = db.execute('SELECT refID FROM refs WHERE gameID ="' + row[4] + '" AND pieceID ="' + row[5] + '"')
        target = False 
        for r1 in isTarget:
            target = True
        if not target:
            continue
    print(row)
    #TAKE
    #shape, colour, orientation, gridPosition, gameID, pieceID = row
    #piece = colour  #+ "_" + shape #shape + "_" + colour
    
    #PENTOCV
    piece, gameID, text, uttID = row
    pair_num = gameID.split("_")[0]
    #if not pair_num == PAIR_NUM:
    #    continue
    
    piece_counter[piece] += 1
    
    if CORPUS in ["TAKECV", "TAKE"]:
        local_word_count = Counter()
        feature_vector = {}
        for f in db.execute('SELECT word from words WHERE gameID ="' + str(gameID) + '"'):
            #print(f)
            for word in clean_utt(f[0].lower()).split():
                local_word_count[word] += 1
        word_dem = len(local_word_count.values())
        for k, v in local_word_count.items():
            feature_vector[k] = local_word_count[k]/word_dem
            word_counter[k] += (v/word_dem)
            word_piece_counter[piece+"__"+k] += (v/word_dem)
    elif CORPUS == "PENTOCV":
        word_dem = len(clean_utt(text.lower()).split())
        feature_vector = {}
        local_word_count = Counter()
        for word in clean_utt(text.lower()).split():
            word_counter[word] += (1/word_dem)
            word_piece_counter[piece+"__"+word] += (1/word_dem)
            local_word_count[word] += 1
        for k, v in local_word_count.items():
            feature_vector[k] = local_word_count[k]/word_dem
        if pair_num == PAIR_NUM:
            test_data.append((feature_vector, piece))
        else:
            train_data.append((feature_vector, piece))
# Out:
# ('L', 'r1_1_1_b', 'das <v="orange">orangene</v> $L', 5887)
# ('X', 'r1_1_1_b', 'das Kreuz', 5893)
# ('X', 'r1_1_1_b', 'es', 5893)
# ('T', 'r1_1_1_b', 'es', 5899)
# ('T', 'r1_1_1_b', '(<p>d-</p> + das) grüne $T', 5901)
# ('T', 'r1_1_1_b', 'das $T', 5903)
# ('T', 'r1_1_1_b', 'das $T', 5907)
# ('T', 'r1_1_1_b', 'das $T', 5907)
# ('T', 'r1_1_1_b', '<v="es">\'s</v>', 5909)
# ('U', 'r1_1_1_b', 'das gelbe', 5919)
# ('U', 'r1_1_1_b', 'die Brücke', 5921)
# ('P', 'r1_1_1_b', 'das pinkfarbene Teil', 5924)
# ('I', 'r1_1_2_b', 'den blauen Balken', 5935)
# ('V', 'r1_1_2_b', 'das blaue $L', 5937)
# ('L', 'r1_1_2_b', 'das <v="orange">orangene</v> $L', 5939)
# ('L', 'r1_1_2_b', 'es', 5939)
# ('Z', 'r1_1_2_b', 'das $S', 5952)
# ('Z', 'r1_1_2_b', 'es', 5952)
# ('Z', 'r1_1_2_b', '<v="es">\'s</v> da', 5963)
# ('V', 'r1_1_2_b', 'den blauen', 5963)
# ('P', 'r1_1_2_b', 'das pinkfarbene Teil', 5969)
# ('P', 'r1_1_2_b', 'es', 5969)
# ('P', 'r1_1_3_b', 'das pinke Teil', 5982)
# ('P', 'r1_1_3_b', 'es', 5982)
# ('W', 'r1_1_3_b', 'grüne Treppe', 5984)
# ('W', 'r1_1_3_b', 'sie', 5988)
# ('W', 'r1_1_3_b', 'die grüne Treppe', 5988)
# ('U', 'r1_1_3_b', 'die: gelbe Brücke', 5997)
# ('P', 'r1_1_3_b', 'das pinkfarbene', 5997)
# ('Y', 'r1_1_3_b', 'das braune Klötzchen', 6003)
# ('Y', 'r1_1_3_b', 'es', 6003)
# ('W', 'r1_1_3_b', 'Grüne', 6006)
# ('W', 'r1_1_3_b', 'Grüne', 6007)
# ('T', 'r1_1_3_b', '(das $T + das grüne $T)', 6011)
# ('Y', 'r1_1_3_b', 'das braune', 6011)
# ('T', 'r1_1_3_b', '$T-Strich', 6011)
# ('Y', 'r1_1_3_b', 'braune', 6013)
# ('F', 'r1_1_3_b', 'dieses graue', 6016)
# ('W', 'r1_1_3_s', 'die Treppe', 5978)
# ('L', 'r1_1_4_b', 'das <v="orange">orangene</v> Teil', 6027)
# ('L', 'r1_1_4_b', 'es', 6027)
# ('P', 'r1_1_4_b', 'das pinkfarbene Teil', 6036)
# ('L', 'r1_1_4_b', '. <v="orange">orangene</v>', 6038)
# ('Y', 'r1_1_4_b', 'das: {F ähm} blaue', 6041)
# ('Y', 'r1_1_4_b', '(<p>d-</p> + das) braune', 6055)
# ('Y', 'r1_1_4_b', 'das braune', 6056)
# ('P', 'r1_1_4_b', '{F ähm} pinkfarbene', 6060)
# ('P', 'r1_1_4_b', 'dem pinkfarbenen', 6066)
# ('N', 'r1_1_4_b', 'lila Teil', 6072)
# ('L', 'r1_1_4_b', 'des orangefarbenen Teils', 6072)
# ('L', 'r1_1_4_b', 'des orangefarbenen Teils', 6076)
# ('N', 'r1_1_4_b', 'des: ... lila Teils', 6085)
# ('L', 'r1_1_4_b', 'des <v="orangen">orangenen</v>', 6085)
# ('N', 'r1_1_4_b', 'das', 6099)
# ('Y', 'r1_1_4_b', 'das braune . Klötzchen', 6119)
# ('Y', 'r1_1_4_b', 'es', 6119)
# ('P', 'r1_1_4_b', 'das .. pinkfarbene', 6119)
# ('N', 'r1_1_4_b', 'das lilafarbene', 6119)
# ('X', 'r1_1_4_b', 'das rote Kreuz', 6124)
# ('U', 'r1_1_4_b', 'die gelbe Brücke', 6125)
# ('Y', 'r1_1_4_s', 'das braune', 6023)
# ('U', 'r1_1_5_b', 'die Brücke', 6151)
# ('X', 'r1_1_5_b', 'das rote Kreuz', 6153)
# ('I', 'r1_1_5_b', 'den blauen Balken', 6155)
# ('N', 'r1_1_5_b', 'das lila Teil', 6157)
# ('I', 'r1_1_5_b', 'dem blauen Balken', 6157)
# ('X', 'r1_1_5_b', 'das rote', 6157)
# ('X', 'r1_1_5_b', 'rotes Kreuz', 6157)
# ('W', 'r1_1_5_b', 'die grüne Treppe', 6172)
# ('N', 'r1_1_5_b', 'lila', 6172)
# ('T', 'r1_1_5_b', 'das $T', 6175)
# ('W', 'r1_1_5_b', 'das grüne', 6175)
# ('Y', 'r1_1_5_b', 'das braune Gebilde', 6179)
# ('Y', 'r1_1_5_b', 'das braune Gebilde', 6185)
# ('T', 'r1_1_5_b', 'das $T', 6185)
# ('T', 'r1_1_5_b', 'des $T', 6185)
# ('F', 'r1_1_5_b', 'dieses . graue Teil', 6193)
# ('T', 'r1_1_5_b', '$T', 6193)
# ('Y', 'r1_1_5_b', 'braun', 6193)
# ('W', 'r1_1_5_s', 'die grüne Treppe', 6143)
# ('X', 'r1_1_5_s', 'rotes Kreuz', 6145)
# ('I', 'r1_1_5_s', 'das blaue Klötzchen', 6147)
# ('U', 'r1_1_6_b', 'Brücke', 6232)
# ('X', 'r1_1_6_b', 'das rote Kreuz', 6235)
# ('L', 'r1_1_6_b', 'das <v="orange">orangene</v> Teil', 6237)
# ('X', 'r1_1_6_b', 'rote Kreuz', 6237)
# ('T', 'r1_1_6_b', 'das grüne $T', 6243)
# ('P', 'r1_1_6_b', 'das pinkfarbene Teil', 6245)
# ('T', 'r1_1_6_s', 'ein $T', 6225)
# ('I', 'r1_1_7_b', 'den blauen: Holzklotz', 6260)
# ('L', 'r1_1_7_b', 'das <v="orange">orangene</v> Teil', 6265)
# ('I', 'r1_1_7_b', 'das linke blaue', 6265)
# ('L', 'r1_1_7_b', 'des <v="orangen">orangenen</v> Teils', 6274)
# ('U', 'r1_1_7_b', 'die Brücke', 6277)
# ('L', 'r1_1_7_b', 'das <v="orange">orangene</v>', 6277)
# ('L', 'r1_1_7_b', '<v="orange">orangene</v>', 6277)
# ('X', 'r1_1_7_b', 'das rote Kreuz', 6282)
# ('Y', 'r1_1_7_b', 'das braune', 6290)
# ('I', 'r1_1_7_b', 'das blaue', 6290)
# ('I', 'r1_1_7_b', 'dem blauen', 6301)
# ('F', 'r1_1_7_b', 'das graue', 6305)
# ('N', 'r1_1_7_b', 'das lilafarbene Teil', 6311)
# ('N', 'r1_1_7_s', 'dieses <v="eckige">e:ckiche</v>', 6250)
# ('U', 'r1_1_7_s', 'die Brücke', 6256)
# ('U', 'r1_1_8_b', 'die Brücke', 6326)
# ('P', 'r1_1_8_b', 'das rosa Teil', 6329)
# ('V', 'r1_1_8_b', 'das blaue', 6335)
# ('P', 'r1_1_8_b', 'das rosa Teil', 6335)
# ('P', 'r1_1_9_b', 'das pinkfarbene Teil', 6349)
# ('P', 'r1_1_9_b', 'dran', 6353)
# ('F', 'r1_1_9_b', 'das entsetzliche graue Teil', 6353)
# ('F', 'r1_1_9_b', 'das graue Teil', 6354)
# ('P', 'r1_1_9_b', 'das {F ähm} pinkfarbene', 6354)
# ('P', 'r1_1_9_b', 'pinkfarbene', 6356)
# ('X', 'r1_1_9_b', 'das rote Kreuz', 6360)
# ('W', 'r1_1_9_b', 'die Treppe', 6364)
# ('T', 'r1_1_9_b', 'das $T', 6366)
# ('T', 'r1_1_9_b', 'das $T', 6368)
# ('W', 'r1_1_9_b', 'die Treppe', 6371)
# ('T', 'r1_1_9_b', '$T-Stück', 6373)
# ('T', 'r1_2_14_s', 'ein $T', 6380)
# ('P', 'r1_2_14_s', 'das rosa Tei:l', 6380)
# ('U', 'r1_2_14_s', 'die Brücke', 6380)
# ('I', 'r2_1_1_b', 'der Eins', 12514)
# ('L', 'r2_1_1_b', 'das', 12548)
# ('F', 'r2_1_1_b', 'grau', 12550)
# ('L', 'r2_1_1_b', 'orange', 12552)
# ('Y', 'r2_1_1_b', 'braun', 12556)
# ('F', 'r2_1_1_b', 'das grau', 12558)
# ('I', 'r2_1_1_b', 'sie', 13271)
# ('I', 'r2_1_1_b', 'das lange Blaue', 13275)
# ('Z', 'r2_1_1_b', 'dieses ... $Z', 13281)
# ('N', 'r2_1_1_b', 'dieses <v="lila">lilane</v>', 13283)
# ('Z', 'r2_1_1_b', 'das', 13285)
# ('I', 'r2_1_1_b', 'das . lange Blaue', 13285)
# ('N', 'r2_1_1_b', '{F äh} <v="lila">lilanen</v>', 13293)
# ('W', 'r2_1_1_b', 'das $W', 13296)
# ('W', 'r2_1_1_b', 'es', 13300)
# ('W', 'r2_1_1_b', 'das <unsure>$M</unsure>', 13300)
# ('W', 'r2_1_1_b', '<v="ein">\'n</v> $M', 13300)
# ('W', 'r2_1_1_b', '<v="ein">\'n</v> . (<p="grünes">grün-</p> + .. grünes) Ding', 13306)
# ('W', 'r2_1_1_b', '$M', 13306)
# ('T', 'r2_1_1_b', 'das $T', 13314)
# ('L', 'r2_1_1_b', 'die Eins', 13319)
# ('Y', 'r2_1_1_b', 'die Eins', 13324)
# ('Y', 'r2_1_1_b', 'braun', 13328)
# ('Y', 'r2_1_1_b', 'braun', 13329)
# ('Y', 'r2_1_1_b', 'es', 13334)
# ('Y', 'r2_1_1_b', 'das Ding', 13341)
# ('Y', 'r2_1_1_b', 'braun', 13344)
# ('Y', 'r2_1_1_b', 'der . Eins', 13349)
# ('Y', 'r2_1_1_b', 'dem braunen', 13349)
# ('Y', 'r2_1_1_b', 'das', 13351)
# ('Y', 'r2_1_1_b', 'es', 13351)
# ('T', 'r2_1_1_b', 'das $T', 13351)
# ('F', 'r2_1_1_b', 'das Graue', 13353)
# ('F', 'r2_1_1_b', 'es">wie\'s</v> jetzt <v="ist">is\'</v> und steckst <ref id="F" piece="target"> es', 13355)
# ('X', 'r2_1_1_b', 'das Plus', 13357)
# ('U', 'r2_1_1_b', 'das $C', 13359)
# ('X', 'r2_1_1_s', 'plus', 12454)
# ('W', 'r2_1_1_s', '$W', 12456)
# ('T', 'r2_1_1_s', '$T', 12458)
# ('X', 'r2_1_1_s', 'ein Plus', 12464)
# ('W', 'r2_1_1_s', '$W', 12466)
# ('U', 'r2_1_1_s', '$C', 12468)
# ('L', 'r2_1_1_s', 'die Eins', 12484)
# ('Z', 'r2_1_1_s', '<v="ein">\'n</v> $Z', 12490)
# ('T', 'r2_1_1_s', 'ein $T', 13221)
# ('W', 'r2_1_1_s', 'dieses $W', 13237)
# ('L', 'r2_1_1_s', '<v="eine">\'ne</v> Eins', 13240)
# ('Y', 'r2_1_1_s', 'braun', 13242)
# ('I', 'r2_1_1_s', '<v="ein">\'n</v> ganz langes blaues', 13248)
# ('N', 'r2_1_1_s', 'lila', 13252)
# ('F', 'r2_1_1_s', 'grau', 13261)
# ('F', 'r2_1_1_s', 'Eins', 13263)
# ('N', 'r2_1_2_b', '<v="lila">lilanes</v> ... $Z', 13390)
# ('N', 'r2_1_2_b', 'das <v="lila">lilane</v> $Z', 13390)
# ('L', 'r2_1_2_b', 'dem orangen', 13396)
# ('L', 'r2_1_2_b', 'der Eins', 13396)
# ('L', 'r2_1_2_b', 'das', 13398)
# ('Z', 'r2_1_2_b', 'das $Z', 13404)
# ('N', 'r2_1_2_b', 'dem <v="lila">lilanen</v>', 13417)
# ('L', 'r2_1_2_b', 'diesem $L', 13417)
# ('V', 'r2_1_2_b', 'dem blauen', 13417)
# ('V', 'r2_1_2_b', 'das', 13419)
# ('V', 'r2_1_2_b', 'es', 13425)
# ('Z', 'r2_1_2_b', 'dem . Ding', 13431)
# ('Z', 'r2_1_2_b', 'das letzte Teil', 13433)
# ('Z', 'r2_1_2_b', 'es', 13439)
# ('Z', 'r2_1_2_s', 'ein {F äh} ... $Z', 12586)
# ('Z', 'r2_1_2_s', 'blaues $Z', 12588)
# ('L', 'r2_1_2_s', 'eine <v="orange">orangene</v> Eins', 12590)
# ('W', 'r2_1_3_b', 'dem {F äh} . grünen $W', 13459)
# ('W', 'r2_1_3_b', '$W', 13461)
# ('W', 'r2_1_3_b', '$M', 13461)
# ('W', 'r2_1_3_b', 'das', 13461)
# ('T', 'r2_1_3_b', 'das $T', 13474)
# ('T', 'r2_1_3_b', '(das grüne + . das dunkelgrüne)', 13474)
# ('T', 'r2_1_3_b', 'das', 13476)
# ('X', 'r2_1_3_b', 'das rote Plus', 13480)
# ('X', 'r2_1_3_b', 'das', 13482)
# ('T', 'r2_1_3_b', 'umgedrehte $T', 13482)
# ('F', 'r2_1_3_b', 'das linke', 13484)
# ('F', 'r2_1_3_b', 'das graue Teil', 13487)
# ('P', 'r2_1_3_b', 'pinke Teil', 13491)
# ('P', 'r2_1_3_b', 'pink', 13502)
# ('F', 'r2_1_3_b', 'grau', 13504)
# ('P', 'r2_1_3_b', 'das pinke', 13506)
# ('F', 'r2_1_3_b', 'das graue', 13508)
# ('P', 'r2_1_3_b', 'das pinke', 13512)
# ('P', 'r2_1_3_b', 'es', 13514)
# ('P', 'r2_1_3_s', 'das .. Teil', 12606)
# ('F', 'r2_1_3_s', 'das Teil', 12608)
# ('X', 'r2_1_3_s', '<v="ein">\'n</v> Plus', 12612)
# ('X', 'r2_1_3_s', 'das Ding', 13453)
# ('I', 'r2_1_4_b', 'ganz geraden', 13556)
# ('I', 'r2_1_4_b', 'das Ding', 13566)
# ('I', 'r2_1_4_b', 'was', 13566)
# ('I', 'r2_1_4_b', 'das', 13566)
# ('I', 'r2_1_4_b', 'es">wie\'s</v>', 13568)
# ('L', 'r2_1_4_b', '(die + {F äh} ... die Eins) die . <v="orange">orangene</v>', 13570)
# ('L', 'r2_1_4_b', 'das', 13574)
# ('X', 'r2_1_4_b', 'das Plus', 13580)
# ('X', 'r2_1_4_b', 'es', 13580)
# ('N', 'r2_1_4_b', 'dieses .. {F äh} . <v="lila">lilane</v> ... $Z', 13586)
# ('F', 'r2_1_4_b', '$F', 13588)
# ('N', 'r2_1_4_b', 'es', 13594)
# ('X', 'r2_1_4_b', 'Plus', 13594)
# ('N', 'r2_1_4_b', '(das + ... das) $W', 13598)
# ('W', 'r2_1_4_b', '$M', 13599)
# ('W', 'r2_1_4_b', 'das', 13601)
# ('N', 'r2_1_4_b', 'dem ... <v="lila">lilanen</v>', 13601)
# ('X', 'r2_1_4_b', 'Plus', 13601)
# ('W', 'r2_1_4_b', 'es', 13602)
# ('W', 'r2_1_4_b', 'das $M', 13609)
# ('U', 'r2_1_4_b', 'das . $C', 13611)
# ('Y', 'r2_1_4_b', '(diese + die) braune Eins', 13617)
# ('Y', 'r2_1_4_b', 'das', 13621)
# ('U', 'r2_1_4_b', '$C', 13621)
# ('N', 'r2_1_4_b', '<v="lila">lilanen</v>', 13621)
# ('Y', 'r2_1_4_b', 'das', 13623)
# ('V', 'r2_1_4_b', 'das blaue', 13625)
# ('N', 'r2_1_4_b', 'dem <v="lila">lilanen</v>', 13635)
# ('T', 'r2_1_4_b', 'das grüne $T', 13637)
# ('Z', 'r2_1_4_b', 'das', 13651)
# ('F', 'r2_1_4_b', 'es', 13657)
# ('Y', 'r2_1_4_b', 'dieses braune', 13657)
# ('F', 'r2_1_4_b', 'das {F äh} graue Teilchen', 13661)
# ('F', 'r2_1_4_b', 'den', 13665)
# ('P', 'r2_1_4_b', 'das .. pinke', 13667)
# ('P', 'r2_1_4_b', 'der', 13671)
# ('F', 'r2_1_4_b', 'die Eins', 13671)
# ('L', 'r2_1_4_b', 'sie', 13673)
# ('U', 'r2_1_4_s', '$C', 12628)
# ('Y', 'r2_1_4_s', 'braune Eins', 12630)
# ('Z', 'r2_1_4_s', 'türkise $Z', 12632)
# ('Z', 'r2_1_4_s', 'das einzige $Z', 12636)
# ('Z', 'r2_1_4_s', 'türkis', 13533)
# ('Z', 'r2_1_4_s', 'türkis', 13533)
# ('N', 'r2_1_4_s', 'das grade lila', 13537)
# ('Z', 'r2_1_4_s', 'blau', 13539)
# ('Z', 'r2_1_4_s', 'blau', 13541)
# ('U', 'r2_1_4_s', '$C', 13545)
# ('Y', 'r2_1_5_b', '<v="eine">\'ne</v> Eins', 12718)
# ('V', 'r2_1_5_b', 'dem Winkel', 13707)
# ('V', 'r2_1_5_b', 'der', 13708)
# ('U', 'r2_1_5_b', 'das gelbe $C', 13720)
# ('U', 'r2_1_5_b', 'das', 13730)
# ('F', 'r2_1_5_b', 'das graue Ding', 13736)
# ('U', 'r2_1_5_b', 'das $C', 13745)
# ('W', 'r2_1_5_b', 'das $W', 13747)
# ('W', 'r2_1_5_b', 'das', 13749)
# ('W', 'r2_1_5_b', 'das .. Ding', 13751)
# ('T', 'r2_1_5_b', 'das grüne $T', 13759)
# ('T', 'r2_1_5_b', 'es', 13763)
# ('T', 'r2_1_5_b', 'dem $T-Steg', 13766)
# ('I', 'r2_1_5_b', 'das ganz ganz Lange', 13768)
# ('I', 'r2_1_5_b', 'das blaue', 13770)
# ('L', 'r2_1_5_b', 'die Eins', 13776)
# ('L', 'r2_1_5_b', 'die', 13777)
# ('L', 'r2_1_5_b', 'die Eins', 13777)
# ('L', 'r2_1_5_b', '<v="eine">\'ne</v> Eins', 13777)
# ('L', 'r2_1_5_b', 'damit', 13782)
# ('Y', 'r2_1_5_b', 'die braune Eins', 13786)
# ('L', 'r2_1_5_b', 'die . <v="orange">orangene</v> Eins', 13786)
# ('Y', 'r2_1_5_b', 'das Dingen', 13788)
# ('X', 'r2_1_5_b', 'das Plus', 13797)
# ('Z', 'r2_1_5_b', 'das {F äh} .. türkise Ding', 13799)
# ('X', 'r2_1_5_b', 'im . Plus', 13799)
# ('V', 'r2_1_5_s', 'Winkel', 12697)
# ('I', 'r2_1_5_s', 'Balken', 12699)
# ('Y', 'r2_1_5_s', 'normale Eins', 12701)
# ('X', 'r2_1_5_s', 'das Plus', 12705)
# ('L', 'r2_1_5_s', 'die normale Eins', 13689)
# ('V', 'r2_2_6_b', 'den blauen Winkel', 12738)
# ('Z', 'r2_2_6_b', 'das . $Z', 12744)
# ('Z', 'r2_2_6_b', 'das', 12748)
# ('Z', 'r2_2_6_b', 'das', 12748)
# ('Z', 'r2_2_6_b', 'es', 12748)
# ('I', 'r2_2_6_b', 'den langen Balken', 12753)
# ('I', 'r2_2_6_b', 'es', 12753)
# ('Z', 'r2_2_6_b', 'das $Z', 12753)
# ('P', 'r2_2_6_b', 'das pinke Teil', 12755)
# ('L', 'r2_2_6_b', 'die <v="orange">orangene</v> Eins', 12768)
# ('L', 'r2_2_6_b', 'es', 12781)
# ('N', 'r2_2_6_b', 'da:s <v="lila">lilane</v> $Z', 12785)
# ('T', 'r2_2_6_b', '$T', 12793)
# ('Y', 'r2_2_6_b', '(bl- + {F äh} braunen) Eins', 12793)
# ('Z', 'r2_2_6_b', '$Z', 12795)
# ('Y', 'r2_2_6_b', 'das braune Teil', 12797)
# ('X', 'r2_2_6_b', 'das Plus', 12799)
# ('X', 'r2_2_6_b', 'es', 12799)
# ('U', 'r2_2_6_b', '$C', 12801)
# ('X', 'r2_2_6_b', 'das Plus', 12801)
# ('U', 'r2_2_6_s', 'das {F äh} gelbe $C', 13809)
# ('L', 'r2_2_6_s', 'die <v="orange">orangene</v> Eins', 13811)
# ('P', 'r2_2_6_s', 'das . pinke Ding', 13813)
# ('I', 'r2_2_7_b', 'den langen Balken', 12826)
# ('I', 'r2_2_7_b', 'den', 12828)
# ('Y', 'r2_2_7_b', 'die . braune Eins', 12831)
# ('W', 'r2_2_7_b', 'das $W', 12840)
# ('W', 'r2_2_7_b', 'es:', 12844)
# ('V', 'r2_2_7_b', 'es', 12846)
# ('Y', 'r2_2_7_b', 'dem braunen Teil', 12846)
# ('V', 'r2_2_7_b', 'den Winkel', 12852)
# ('T', 'r2_2_7_b', 'grüne $T', 12860)
# ('Z', 'r2_2_7_b', 'das $Z', 12863)
# ('Z', 'r2_2_7_b', 'das', 12865)
# ('F', 'r2_2_7_b', 'die . Eins mit dem Nupsi', 12882)
# ('U', 'r2_2_7_b', 'dem $C', 12884)
# ('N', 'r2_2_7_b', 'das <v="lila">lilane</v> $Z', 13835)
# ('W', 'r2_2_7_s', 'das $W', 13831)
# ('Y', 'r2_2_7_s', 'die braune Ei:ns', 13831)
# ('I', 'r2_2_7_s', 'den langen Balken', 13831)
# ('W', 'r2_2_8_b', 'dem $W', 12899)
# ('W', 'r2_2_8_b', 'das . $W', 12902)
# ('W', 'r2_2_8_b', 'es', 12902)
# ('W', 'r2_2_8_b', '$W', 12916)
# ('X', 'r2_2_8_b', 'das Plus', 12916)
# ('V', 'r2_2_8_b', 'das blaue $C', 12923)
# ('V', 'r2_2_8_b', 'das Ganze', 12923)
# ('P', 'r2_2_8_b', 'es', 12927)
# ('X', 'r2_2_8_b', 'das Plus', 12927)
# ('Y', 'r2_2_8_b', 'die braune Eins', 12934)
# ('Y', 'r2_2_8_b', 'sie', 12941)
# ('Y', 'r2_2_8_b', 'sie', 12943)
# ('Y', 'r2_2_8_b', 'sie', 12945)
# ('V', 'r2_2_8_b', 'den', 12952)
# ('V', 'r2_2_8_b', 'den', 12960)
# ('U', 'r2_2_8_b', 'das $C', 12964)
# ('U', 'r2_2_8_b', 'es', 12968)
# ('U', 'r2_2_8_b', 'es', 12968)
# ('F', 'r2_2_8_b', 'das graue Teil', 12979)
# ('T', 'r2_2_8_b', 'das $T', 12986)
# ('T', 'r2_2_8_b', 'des $Ts', 12988)
# ('T', 'r2_2_8_b', 'es', 12992)
# ('I', 'r2_2_8_b', 'das {F äh} lange blaue', 12996)
# ('I', 'r2_2_8_b', 'es', 12996)
# ('T', 'r2_2_8_b', 'des $Ts', 13002)
# ('N', 'r2_2_8_b', 'das <v="lila">lilane</v> $Z', 13006)
# ('N', 'r2_2_8_b', 'es', 13010)
# ('P', 'r2_2_8_b', 'es', 13012)
# ('P', 'r2_2_8_b', 'es', 13012)
# ('W', 'r2_2_8_b', 'dem $E', 13012)
# ('W', 'r2_2_8_b', '$E', 13014)
# ('P', 'r2_2_8_b', 'das pinke Teil', 13020)
# ('N', 'r2_2_8_b', 'das lila <p="Ding">Dingen</p>', 13024)
# ('L', 'r2_2_8_b', 'das <v="orange">orangene</v> . Teil', 13026)
# ('L', 'r2_2_8_s', 'die . (rote + . <v="orange">orangene</v>) Eins', 12890)
# ('L', 'r2_2_8_s', '<unclear/> <v="orange">orangene</v> Eins', 12891)
# ('X', 'r2_2_8_s', 'das Plus', 13841)
# ('P', 'r2_2_8_s', 'das pinke', 13841)
# ('L', 'r2_2_8_s', 'die <v="orange">orangene</v> Eins', 13841)
# ('L', 'r2_2_9_b', 'die <v="orange">orangene</v> Eins', 13058)
# ('T', 'r2_2_9_b', 'dem $T', 13066)
# ('T', 'r2_2_9_b', 'des $Ts', 13072)
# ('I', 'r2_2_9_b', 'der Balken', 13072)
# ('I', 'r2_2_9_b', 'des Balkens', 13077)
# ('P', 'r2_2_9_b', 'das pinke Teil', 13077)
# ('X', 'r2_2_9_b', 'das Plus', 13097)
# ('X', 'r2_2_9_b', 'es', 13099)
# ('T', 'r2_2_9_b', 'des $Ts', 13099)
# ('W', 'r2_2_9_b', 'das ... $W', 13101)
# ('W', 'r2_2_9_b', '<v="ein">\'n</v> $M', 13101)
# ('W', 'r2_2_9_b', '$M', 13103)
# ('X', 'r2_2_9_b', 'des Plusses', 13111)
# ('X', 'r2_2_9_b', 'das Plus', 13113)
# ('F', 'r2_2_9_b', 'die graue Eins', 13129)
# ('F', 'r2_2_9_b', 'es', 13133)
# ('U', 'r2_2_9_b', 'das', 13139)
# ('X', 'r2_2_9_b', 'des Pluses', 13139)
# ('N', 'r2_2_9_b', 'das', 13143)
# ('Z', 'r2_2_9_b', 'des $Zs', 13151)
# ('F', 'r2_2_9_b', 'der grauen Eins', 13151)
# ('Z', 'r2_2_9_b', 'das .. $Z', 13160)
# ('U', 'r2_2_9_b', '$C', 13160)
# ('U', 'r2_2_9_b', '$U', 13160)
# ('U', 'r2_2_9_b', 'das gelbe', 13161)
# ('Y', 'r2_2_9_b', 'die braune Eins', 13171)
# ('Y', 'r2_2_9_b', 'es', 13177)
# ('Z', 'r2_2_9_b', 'das $Z', 13180)
# ('Z', 'r2_2_9_b', 'das:', 13182)
# ('Z', 'r2_2_9_b', 'es', 13182)
# ('Z', 'r2_2_9_b', 'das', 13185)
# ('P', 'r2_2_9_b', '(mit dem pinken + mit dieser pinken) Ecke', 13191)
# ('X', 'r2_2_9_b', 'Plus', 13195)
# ('X', 'r2_2_9_b', 'das Plus', 13197)
# ('Z', 'r2_2_9_b', '$S', 13893)
# ('L', 'r2_2_9_s', 'das', 13054)
# ('T', 'r2_2_9_s', 'das grüne $T', 13861)
# ('X', 'r2_2_9_s', 'das Plus', 13861)
# ('Y', 'r2_2_9_s', 'die braune Eins', 13861)
# ('L', 'r3_1_1_b', 'das $L', 7900)
# ('U', 'r3_1_1_b', 'gelben Stein', 8886)
# ('X', 'r3_1_1_b', 'das rote Kreuz', 8893)
# ('U', 'r3_1_1_b', '<v="daran">dran</v>', 8897)
# ('L', 'r3_1_1_b', 'der <v="orange">orangene</v> Stein', 8897)
# ('X', 'r3_1_1_b', 'Daran', 8902)
# ('T', 'r3_1_1_b', 'das grüne . $T', 8902)
# ('U', 'r3_1_1_s', 'den gelben Stein', 7884)
# ('L', 'r3_1_1_s', 'de:n . <v="orangen"> orangenen </v>', 7886)
# ('Z', 'r3_1_2_b', 'Der', 7949)
# ('I', 'r3_1_2_b', 'der lange', 7949)
# ('V', 'r3_1_2_b', 'der blaue Winkel', 8931)
# ('V', 'r3_1_2_b', 'das', 8936)
# ('V', 'r3_1_2_b', 'Daran', 8940)
# ('U', 'r3_1_2_b', 'der gelbe Stein', 8940)
# ('U', 'r3_1_2_b', 'er', 8943)
# ('F', 'r3_1_2_b', 'der graue Stein', 8946)
# ('U', 'r3_1_2_b', 'den gelben', 8953)
# ('W', 'r3_1_2_b', 'der grüne Stein', 8959)
# ('U', 'r3_1_2_b', 'den gelben', 8967)
# ('F', 'r3_1_2_b', 'den . grauen', 8967)
# ('T', 'r3_1_2_b', 'das grüne $T', 8970)
# ('T', 'r3_1_2_b', 'das grüne $T', 8977)
# ('N', 'r3_1_2_b', 'der <v="lila">lilane</v> Stein', 8977)
# ('T', 'r3_1_2_b', 'das $T', 8979)
# ('X', 'r3_1_2_b', 'das {F äh} rote Kreuz', 8986)
# ('X', 'r3_1_2_b', 'das Kreuz', 8990)
# ('N', 'r3_1_2_b', 'den <v="lila">lilanen</v> Stein', 8990)
# ('Y', 'r3_1_2_b', 'der braune Stein', 8990)
# ('X', 'r3_1_2_b', 'das Kreuz', 8998)
# ('Y', 'r3_1_2_b', 'den braunen Stein', 8998)
# ('Z', 'r3_1_2_b', 'der blaue Stein', 8998)
# ('Z', 'r3_1_2_b', 'der', 9000)
# ('P', 'r3_1_2_b', 'der {F ähm} ... pinke Stein', 9004)
# ('P', 'r3_1_2_b', 'den blauen', 9007)
# ('Y', 'r3_1_2_b', 'den braunen Stein', 9019)
# ('L', 'r3_1_2_b', 'de:r . <v="orange">orangene</v> Winkel', 9019)
# ('I', 'r3_1_2_b', 'der blaue Balken', 9023)
# ('Y', 'r3_1_2_s', 'diesen Braunen', 7915)
# ('V', 'r3_1_2_s', 'den blauen .. Winkel', 7917)
# ('T', 'r3_1_2_s', 'das grüne $T', 7919)
# ('T', 'r3_1_2_s', 'das grüne $T', 8920)
# ('F', 'r3_1_3_b', 'Den', 8000)
# ('W', 'r3_1_3_b', 'die Treppe', 8006)
# ('V', 'r3_1_3_b', 'Der', 8018)
# ('Z', 'r3_1_3_b', 'Der', 8020)
# ('L', 'r3_1_3_b', 'der <v="orange">orangene</v> Winkel', 9042)
# ('F', 'r3_1_3_b', '(dem .. + {F äh} der)', 9044)
# ('F', 'r3_1_3_b', 'das', 9047)
# ('L', 'r3_1_3_b', 'daran', 9047)
# ('F', 'r3_1_3_b', 'der graue Stein', 9047)
# ('V', 'r3_1_3_b', 'den {F äh} Winkel', 9051)
# ('F', 'r3_1_3_b', 'das', 9056)
# ('W', 'r3_1_3_b', 'der ... hellgrüne Stein', 9073)
# ('W', 'r3_1_3_b', 'der', 9073)
# ('W', 'r3_1_3_b', 'die Treppe', 9075)
# ('V', 'r3_1_3_b', 'den Winkel', 9077)
# ('W', 'r3_1_3_b', 'die Treppe', 9079)
# ('W', 'r3_1_3_b', 'dem', 9082)
# ('N', 'r3_1_3_b', 'der <v="lila">lilane</v> Stein', 9090)
# ('Z', 'r3_1_3_b', 'der ... hellblaue Stein', 9101)
# ('Z', 'r3_1_3_b', 'der andere', 9103)
# ('Z', 'r3_1_3_b', 'das', 9103)
# ('Z', 'r3_1_3_b', 'das', 9104)
# ('Z', 'r3_1_3_b', 'dem', 9107)
# ('T', 'r3_1_3_b', 'das grüne $T', 9110)
# ('T', 'r3_1_3_b', 'den .. hellblauen', 9112)
# ('U', 'r3_1_3_b', 'der gelbe Stein', 9115)
# ('U', 'r3_1_3_b', 'den gelben Stein', 9120)
# ('X', 'r3_1_3_b', 'das Kreuz', 9120)
# ('P', 'r3_1_3_b', 'der {F ä:hm} pinke Stein', 9122)
# ('X', 'r3_1_3_b', 'das Kreuz', 9128)
# ('V', 'r3_1_3_b', 'der blaue Winkel', 9131)
# ('P', 'r3_1_3_b', 'den {F ähm} pinken Stein', 9133)
# ('T', 'r3_1_3_b', 'dem grünen', 9135)
# ('V', 'r3_1_3_b', '(das + den) blauen Winkel', 9139)
# ('Y', 'r3_1_3_b', 'der braune Stein', 9139)
# ('Y', 'r3_1_3_b', 'den', 9139)
# ('Y', 'r3_1_3_b', 'den', 9148)
# ('I', 'r3_1_3_b', 'das', 9157)
# ('I', 'r3_1_3_b', 'das', 9157)
# ('V', 'r3_1_3_b', 'den blauen', 9158)
# ('U', 'r3_1_3_s', 'den Gelben', 7981)
# ('F', 'r3_1_3_s', 'den Grauen', 7983)
# ('W', 'r3_1_4_b', 'die Treppe', 8058)
# ('P', 'r3_1_4_b', 'der pinke Stein', 9173)
# ('X', 'r3_1_4_b', 'das Kreuz', 9180)
# ('W', 'r3_1_4_b', 'die grüne Treppe', 9184)
# ('W', 'r3_1_4_b', 'die Treppe', 9192)
# ('W', 'r3_1_4_b', 'die Treppe', 9203)
# ('X', 'r3_1_4_b', 'das', 9203)
# ('X', 'r3_1_4_b', 'das Kreuz', 9213)
# ('U', 'r3_1_4_b', 'der gelbe Stein', 9213)
# ('T', 'r3_1_4_b', 'der grüne Stein', 9217)
# ('T', 'r3_1_4_b', 'der grüne', 9219)
# ('L', 'r3_1_4_b', 'der <v="orange">orangene</v> Stein', 9219)
# ('I', 'r3_1_4_b', 'der . blaue Balken', 9227)
# ('I', 'r3_1_4_b', 'der blaue Balken', 9234)
# ('I', 'r3_1_4_b', 'er', 9234)
# ('X', 'r3_1_4_b', 'dem roten Kreuz', 9234)
# ('X', 'r3_1_4_b', 'dem Kreuz', 9234)
# ('I', 'r3_1_4_b', 'er', 9239)
# ('U', 'r3_1_4_b', 'dem gelben', 9239)
# ('W', 'r3_1_4_b', 'den grünen', 9239)
# ('W', 'r3_1_4_b', 'die grüne Treppe', 9239)
# ('I', 'r3_1_4_b', 'den blauen', 9239)
# ('I', 'r3_1_4_b', 'den blauen Balken', 9248)
# ('V', 'r3_1_4_b', 'der blaue Winkel', 9248)
# ('I', 'r3_1_4_b', 'der Balken', 9253)
# ('V', 'r3_1_4_b', 'den Winkel', 9253)
# ('N', 'r3_1_4_b', 'der .. <v="lila">lilane</v> Stein', 9258)
# ('Y', 'r3_1_4_b', 'der', 9272)
# ('V', 'r3_1_4_b', 'blauen Winkel', 9276)
# ('Y', 'r3_1_4_b', 'der', 9283)
# ('V', 'r3_1_4_b', 'dem Winkel', 9283)
# ('N', 'r3_1_4_b', 'den <v="lila">lilanen</v> Stein', 9289)
# ('T', 'r3_1_4_b', 'das $T', 9289)
# ('T', 'r3_1_4_b', 'er', 9291)
# ('Z', 'r3_1_4_b', 'der blaue Stein', 9295)
# ('Z', 'r3_1_4_b', 'der', 9300)
# ('Y', 'r3_1_4_b', 'dem {F äh} braunen Stein', 9300)
# ('Y', 'r3_1_4_b', 'dem brauen Stein', 9307)
# ('N', 'r3_1_4_b', 'dem <v="lila">lilanen</v> Stein', 9307)
# ('F', 'r3_1_4_b', 'der graue Stein', 9311)
# ('F', 'r3_1_4_b', 'der', 9311)
# ('F', 'r3_1_4_b', 'der', 9314)
# ('Y', 'r3_1_4_s', 'Den Braunen', 8048)
# ('P', 'r3_1_4_s', 'den <v="rosa">rosanen</v>', 8050)
# ('X', 'r3_1_4_s', 'das Kreuz', 8052)
# ('X', 'r3_1_4_s', 'das Kreuz', 9167)
# ('V', 'r3_1_5_b', 'der <p="Winkel">Win-</p>', 8121)
# ('N', 'r3_1_5_b', 'das', 8131)
# ('L', 'r3_1_5_b', 'der {F ähm} <v="orange">orangene</v> Stein', 9335)
# ('N', 'r3_1_5_b', 'der {F äh} .. <v="lila">lilane</v> Stein', 9346)
# ('N', 'r3_1_5_b', 'der pinke', 9350)
# ('P', 'r3_1_5_b', 'der rosane', 9352)
# ('P', 'r3_1_5_b', 'der', 9360)
# ('I', 'r3_1_5_b', 'den . Winkel', 9360)
# ('F', 'r3_1_5_b', 'der graue Stein', 9364)
# ('L', 'r3_1_5_b', 'den <v="orangen">orangenen</v>', 9369)
# ('Z', 'r3_1_5_b', 'der hellblaue Stein', 9373)
# ('F', 'r3_1_5_b', 'dem grauen', 9377)
# ('Y', 'r3_1_5_b', 'der {F äh} braune Stein', 9386)
# ('Y', 'r3_1_5_b', 'den {F äh} braunen Stein', 9400)
# ('U', 'r3_1_5_b', 'der gelbe', 9400)
# ('U', 'r3_1_5_b', 'der', 9404)
# ('Y', 'r3_1_5_b', 'braunen', 9404)
# ('W', 'r3_1_5_b', 'die . grüne Treppe', 9408)
# ('W', 'r3_1_5_b', 'die', 9410)
# ('W', 'r3_1_5_b', 'das', 9415)
# ('U', 'r3_1_5_b', 'dem gelben', 9415)
# ('W', 'r3_1_5_b', 'die grüne Treppe', 9419)
# ('Y', 'r3_1_5_b', 'dem braunen Stein', 9419)
# ('N', 'r3_1_5_b', 'der <v="lila">lilane</v> Stein', 9419)
# ('N', 'r3_1_5_b', 'das', 9425)
# ('N', 'r3_1_5_b', 'dem <v="lila">lilanen</v>', 9429)
# ('V', 'r3_1_5_b', 'der .. blaue Winkel', 9429)
# ('T', 'r3_1_5_b', 'das grüne $T', 9433)
# ('V', 'r3_1_5_b', 'dem .. Winkel', 9437)
# ('T', 'r3_1_5_b', 'er', 9442)
# ('N', 'r3_1_5_b', 'den {F ähm} . <v="lila">lilanen</v> Stein', 9446)
# ('X', 'r3_1_5_b', 'das Kreuz', 9446)
# ('I', 'r3_1_5_b', 'der blaue Balken', 9449)
# ('I', 'r3_1_5_s', 'Den blauen Langen', 8110)
# ('P', 'r3_1_5_s', 'de:n rosanen', 8112)
# ('P', 'r3_1_5_s', 'den rosanen', 9328)
# ('T', 'r3_2_10_b', 'das . $T:', 8526)
# ('T', 'r3_2_10_b', '$T', 8533)
# ('I', 'r3_2_10_b', 'den blauen Balken', 8537)
# ('V', 'r3_2_10_b', 'den Winkel', 8547)
# ('V', 'r3_2_10_b', 'Den blauen', 8549)
# ('V', 'r3_2_10_b', 'den', 8553)
# ('I', 'r3_2_10_b', 'den blauen Balken', 8553)
# ('Y', 'r3_2_10_b', 'den: braunen Stein', 8558)
# ('Y', 'r3_2_10_b', 'den', 8558)
# ('V', 'r3_2_10_b', 'den blauen', 8558)
# ('T', 'r3_2_10_b', 'den grünen', 8558)
# ('X', 'r3_2_10_b', 'da:s Kreuz', 8562)
# ('U', 'r3_2_10_b', 'de:n gelben Stein', 8564)
# ('N', 'r3_2_10_b', 'den <v="lila">lilanen</v> Stein', 8568)
# ('N', 'r3_2_10_b', 'Lila', 8570)
# ('N', 'r3_2_10_b', 'den', 8581)
# ('U', 'r3_2_10_b', 'den gelben', 8581)
# ('L', 'r3_2_10_b', 'das $L', 8591)
# ('L', 'r3_2_10_b', 'es', 8597)
# ('U', 'r3_2_10_b', 'dem {F ähm} gelben', 8621)
# ('N', 'r3_2_10_b', 'dem <v="lila">lilanen</v>', 8621)
# ('P', 'r3_2_10_b', 'den <v="rosa">rosanen</v>', 8628)
# ('P', 'r3_2_10_b', 'den', 8632)
# ('Z', 'r3_2_10_b', 'das $Z', 8636)
# ('T', 'r3_2_10_b', 'er', 9536)
# ('N', 'r3_2_10_b', 'er', 9542)
# ('P', 'r3_2_10_s', 'den . rosanen', 9526)
# ('I', 'r3_2_10_s', 'Den blauen Balken', 9530)
# ('N', 'r3_2_10_s', 'den . lilanen', 9532)
# ('P', 'r3_2_11_b', 'dem <v="rosa">rosanen</v>', 8644)
# ('L', 'r3_2_11_b', 'das $L', 8650)
# ('V', 'r3_2_11_b', 'es', 8652)
# ('N', 'r3_2_11_b', 'den <v="lila">lilanen</v> Stein', 8657)
# ('I', 'r3_2_11_b', 'den blauen Balken', 8664)
# ('P', 'r3_2_11_b', 'dem <v="rosa">rosanen</v>', 8666)
# ('L', 'r3_2_11_b', 'dem <v="orangen">orangenen</v>', 8666)
# ('T', 'r3_2_11_b', 'das . $T:', 8669)
# ('I', 'r3_2_11_b', 'dem blauen Balken', 8674)
# ('X', 'r3_2_11_b', 'das Kreuz', 8680)
# ('X', 'r3_2_11_b', 'es', 8680)
# ('I', 'r3_2_11_b', 'de:n blauen Balken', 8680)
# ('T', 'r3_2_11_b', 'das $T', 8680)
# ('W', 'r3_2_11_b', 'die . Treppe', 8686)
# ('X', 'r3_2_11_b', 'Kreuz', 8688)
# ('I', 'r3_2_11_b', 'den blauen Balken', 8688)
# ('Y', 'r3_2_11_b', 'der braune Stein', 8694)
# ('Y', 'r3_2_11_b', 'er', 8694)
# ('T', 'r3_2_11_b', 'das $T', 8696)
# ('X', 'r3_2_11_b', 'das Kreuz', 8696)
# ('Z', 'r3_2_11_b', 'der $Z-Stein', 8700)
# ('Y', 'r3_2_11_b', '(des + den) braunen', 8703)
# ('X', 'r3_2_11_b', 'das $X', 8703)
# ('F', 'r3_2_11_b', 'den grauen Stein', 8711)
# ('F', 'r3_2_11_b', 'es', 8723)
# ('F', 'r3_2_11_b', 'das', 8729)
# ('F', 'r3_2_11_b', 'es', 8729)
# ('T', 'r3_2_11_b', 'dem $T', 8729)
# ('Y', 'r3_2_11_b', 'dem: braunen Stein', 8729)
# ('U', 'r3_2_11_b', 'den gelben Stein', 8735)
# ('V', 'r3_2_11_b', 'Der', 8737)
# ('F', 'r3_2_11_b', 'von dem grauen', 8737)
# ('V', 'r3_2_11_b', 'der Winkel', 8741)
# ('V', 'r3_2_11_b', 'er', 8741)
# ('X', 'r3_2_11_s', 'das Kreuz', 9554)
# ('I', 'r3_2_11_s', 'Den blauen Balken', 9556)
# ('P', 'r3_2_11_s', 'den rosanen', 9558)
# ('X', 'r3_2_12_b', 'das Kreuz', 8755)
# ('L', 'r3_2_12_b', '<v="das">dis</v> <v="orange">orangene</v> $L', 8759)
# ('N', 'r3_2_12_b', 'Den <v="lila">lilanen</v>', 8764)
# ('L', 'r3_2_12_b', 'dem . <v="orangen">orangenen</v>', 8769)
# ('L', 'r3_2_12_b', 'es', 8769)
# ('X', 'r3_2_12_b', 'dem Kreuz', 8773)
# ('F', 'r3_2_12_b', 'den grauen', 8776)
# ('F', 'r3_2_12_b', 'er', 8778)
# ('F', 'r3_2_12_b', 'dieses', 8787)
# ('N', 'r3_2_12_b', 'den . <v="lila">lilanen</v>', 8788)
# ('Z', 'r3_2_12_b', 'diesen $Z-Stein', 8790)
# ('Z', 'r3_2_12_b', '$S-Stein', 8790)
# ('Z', 'r3_2_12_b', '<v="ein">n</v> $Z', 8793)
# ('F', 'r3_2_12_b', 'dem grauen', 8797)
# ('I', 'r3_2_12_b', 'den blauen Balken', 8801)
# ('I', 'r3_2_12_b', 'der', 8804)
# ('Z', 'r3_2_12_b', 'dem $Z', 8804)
# ('P', 'r3_2_12_b', 'de:n <v="rosa">rosanen</v> Stein', 8809)
# ('P', 'r3_2_12_b', 'er', 8809)
# ('L', 'r3_2_12_b', 'dem $L', 8812)
# ('V', 'r3_2_12_b', 'Winkel', 8814)
# ('T', 'r3_2_12_b', 'den $T-Stein', 8818)
# ('T', 'r3_2_12_b', 'er', 8824)
# ('P', 'r3_2_12_b', 'dem {F ö:hm} .. <v="rosa">rosanen</v>', 8824)
# ('T', 'r3_2_12_b', 'den', 8827)
# ('L', 'r3_2_12_b', 'das $L', 8829)
# ('W', 'r3_2_12_b', 'die Treppe', 8832)
# ('W', 'r3_2_12_b', 'sie', 8834)
# ('Z', 'r3_2_12_b', '<v="dieses">dies</v> $Z', 8839)
# ('T', 'r3_2_12_b', 'das $T', 8839)
# ('Z', 'r3_2_12_b', 'dem $Z', 8841)
# ('T', 'r3_2_12_b', 'dem $T', 8841)
# ('V', 'r3_2_12_b', 'den: .. Winkel', 8846)
# ('V', 'r3_2_12_b', 'den . {F äh} <pos> in die untere . Ecke von <ref id="W" piece="landmark" location="target"> der Treppe', 8846)
# ('Y', 'r3_2_12_b', 'den braunen Stein', 8852)
# ('V', 'r3_2_12_b', 'den Winkel', 8855)
# ('U', 'r3_2_12_b', 'de:n gelben', 8862)
# ('T', 'r3_2_12_b', 'den grünen', 8864)
# ('Y', 'r3_2_12_b', 'den braunen', 8864)
# ('I', 'r3_2_12_s', 'den blauen Balken', 9573)
# ('X', 'r3_2_12_s', 'Das Kreuz', 9575)
# ('W', 'r3_2_12_s', 'die Treppe', 9577)
# ('T', 'r3_2_6_b', 'ein $T', 8145)
# ('V', 'r3_2_6_b', 'dem Winkel', 8149)
# ('V', 'r3_2_6_b', 'Der Winkel', 8151)
# ('V', 'r3_2_6_b', 'der blaue', 8151)
# ('Z', 'r3_2_6_b', 'der andere blaue', 8155)
# ('Z', 'r3_2_6_b', '$S', 8155)
# ('Z', 'r3_2_6_b', '$Z', 8155)
# ('I', 'r3_2_6_b', 'den blauen Balken', 8162)
# ('Z', 'r3_2_6_b', 'das $Z', 8165)
# ('L', 'r3_2_6_b', '(de:n <v="orangen">orangenen</v> + das $L)', 8169)
# ('L', 'r3_2_6_b', 'es', 8174)
# ('P', 'r3_2_6_b', 'dem <v="rosa">rosanen</v>', 8179)
# ('N', 'r3_2_6_b', 'der {F äh} <v="lila">lilane</v>', 8183)
# ('L', 'r3_2_6_b', 'das $L', 8185)
# ('Y', 'r3_2_6_b', 'den braunen', 8187)
# ('N', 'r3_2_6_b', 'das <v="lila">lilane</v>', 8190)
# ('X', 'r3_2_6_b', 'das $X', 8194)
# ('X', 'r3_2_6_b', 'das Kreuz', 8196)
# ('U', 'r3_2_6_b', 'den gelben', 8198)
# ('T', 'r3_2_6_b', 'das $T', 8204)
# ('U', 'r3_2_6_s', 'Den gelben', 8143)
# ('U', 'r3_2_6_s', 'den Gelben', 9455)
# ('U', 'r3_2_6_s', 'den Gelben', 9457)
# ('L', 'r3_2_6_s', 'De:n orangenen', 9459)
# ('I', 'r3_2_6_s', 'den blauen Balken', 9461)
# ('U', 'r3_2_7_b', 'de:m gelben', 8213)
# ('X', 'r3_2_7_b', 'das $X', 8213)
# ('T', 'r3_2_7_b', 'das $T', 8216)
# ('T', 'r3_2_7_b', 'das grüne', 8218)
# ('X', 'r3_2_7_b', 'das Kreuz', 8224)
# ('Z', 'r3_2_7_b', 'der $Z-Stein', 8228)
# ('Z', 'r3_2_7_b', 'er', 8228)
# ('T', 'r3_2_7_b', 'dem $T', 8230)
# ('X', 'r3_2_7_b', 'dem $X', 8230)
# ('N', 'r3_2_7_b', 'diesen <v="lila">lilanen</v> Stein', 8237)
# ('N', 'r3_2_7_b', 'der', 8248)
# ('T', 'r3_2_7_b', 'das .. $T', 8248)
# ('P', 'r3_2_7_b', 'den <v="rosa">rosanen</v> Stein', 8253)
# ('N', 'r3_2_7_b', 'dem <v="lila">lilanen</v>', 8260)
# ('W', 'r3_2_7_b', 'die Treppe', 8268)
# ('P', 'r3_2_7_b', 'dem <v="rosa">rosanen</v>', 8274)
# ('N', 'r3_2_7_b', 'dem <v="lila">lilanen</v>', 8274)
# ('F', 'r3_2_7_b', 'den grauen', 8278)
# ('Y', 'r3_2_7_b', 'den braunen', 8296)
# ('Y', 'r3_2_7_b', 'den', 8299)
# ('F', 'r3_2_7_b', 'den grauen', 8299)
# ('I', 'r3_2_7_b', 'den blauen Balken', 8303)
# ('I', 'r3_2_7_b', 'den', 8303)
# ('L', 'r3_2_7_b', 'das $L', 8306)
# ('V', 'r3_2_7_b', 'den Winkel', 8310)
# ('L', 'r3_2_7_b', 'das $L', 8310)
# ('I', 'r3_2_7_s', 'den .. blauen Balken', 9475)
# ('P', 'r3_2_7_s', 'Den rosanen', 9479)
# ('Z', 'r3_2_7_s', 'dieses .. hellblaue', 9481)
# ('Z', 'r3_2_7_s', '$Z', 9481)
# ('I', 'r3_2_8_b', 'dem Balken', 8331)
# ('L', 'r3_2_8_b', 'das <v="orange">orangene</v> $L', 8334)
# ('I', 'r3_2_8_b', 'Balken', 8340)
# ('T', 'r3_2_8_b', 'das grüne $T', 8343)
# ('T', 'r3_2_8_b', 'das', 8345)
# ('L', 'r3_2_8_b', 'dem <v="orangen">orangenen</v>', 8347)
# ('L', 'r3_2_8_b', 'das  . {F äh} $L', 8354)
# ('Z', 'r3_2_8_b', 'dieses $S', 8357)
# ('Z', 'r3_2_8_b', '$Z-Steinchen', 8357)
# ('T', 'r3_2_8_b', 'das $T', 8363)
# ('L', 'r3_2_8_b', 'die <v="orangen">orangenen</v>', 8371)
# ('P', 'r3_2_8_b', 'der <v="rosa">rosane</v>', 8376)
# ('P', 'r3_2_8_b', 'den', 8385)
# ('T', 'r3_2_8_b', 'den grünen', 8385)
# ('N', 'r3_2_8_b', 'den <v="lila">lilanen</v>', 8389)
# ('N', 'r3_2_8_b', 'er', 8391)
# ('N', 'r3_2_8_b', 'den', 8391)
# ('N', 'r3_2_8_b', 'den', 8395)
# ('P', 'r3_2_8_b', 'den <v="rosa">rosanen</v>', 8395)
# ('T', 'r3_2_8_b', 'den grünen', 8395)
# ('Z', 'r3_2_8_b', 'blauen', 8395)
# ('V', 'r3_2_8_b', 'den blauen Winkel', 8399)
# ('V', 'r3_2_8_b', 'den', 8404)
# ('N', 'r3_2_8_b', 'den <v="lila">lilanen</v>', 8404)
# ('F', 'r3_2_8_b', 'den grauen', 8407)
# ('F', 'r3_2_8_b', 'den', 8407)
# ('F', 'r3_2_8_b', 'den', 8407)
# ('X', 'r3_2_8_b', 'das Kreuz', 8411)
# ('W', 'r3_2_8_b', 'die Treppe', 8413)
# ('W', 'r3_2_8_b', 'sie', 8413)
# ('X', 'r3_2_8_b', 'dem $X', 8430)
# ('U', 'r3_2_8_b', 'den', 8436)
# ('Y', 'r3_2_8_b', 'den braunen Stein', 8440)
# ('Y', 'r3_2_8_b', 'den', 8440)
# ('Y', 'r3_2_8_b', 'den', 8447)
# ('W', 'r3_2_8_b', 'den grünen', 8447)
# ('U', 'r3_2_8_b', 'den gelben', 8447)
# ('X', 'r3_2_8_s', 'das Kreuz', 9494)
# ('P', 'r3_2_8_s', 'Den rosanen', 9496)
# ('L', 'r3_2_8_s', 'den orangenen', 9498)
# ('W', 'r3_2_9_b', 'die Treppe', 8465)
# ('T', 'r3_2_9_b', 'das $T', 8471)
# ('W', 'r3_2_9_b', 'die Treppe', 8473)
# ('F', 'r3_2_9_b', 'den grauen', 8479)
# ('F', 'r3_2_9_b', 'er', 8479)
# ('F', 'r3_2_9_b', 'ihn', 8479)
# ('T', 'r3_2_9_b', 'das $T', 8479)
# ('X', 'r3_2_9_b', 'das Kreuz', 8483)
# ('P', 'r3_2_9_b', 'den <v="rosa">rosanen</v>', 8485)
# ('F', 'r3_2_9_b', 'der graue Stein', 8487)
# ('P', 'r3_2_9_b', 'den <v="rosa">rosanen</v>', 8514)
# ('F', 'r3_2_9_b', 'den grauen', 8514)
# ('X', 'r3_2_9_s', 'das Kreuz', 9506)
# ('W', 'r3_2_9_s', 'Die grüne Treppe', 9508)
# ('F', 'r3_2_9_s', 'den {F äh} grauen', 9510)
# ('L', 'r4_', 'de:r {F ähm} <v="orange">orangene</v> (Ba- {F äh ähm} + Winkel)', 10898)
# ('P', 'r4_', 'der <v="rosa">rosane</v> Stein', 10903)
# ('P', 'r4_', 'er', 10903)
# ('V', 'r4_', 'Winkel', 10903)
# ('F', 'r4_', 'der graue Stein', 10907)
# ('F', 'r4_', 'er', 10911)
# ('V', 'r4_', 'den {F äh} Winkel', 10911)
# ('F', 'r4_', 'er', 10911)
# ('Z', 'r4_', 'dieser ... $Z Stein', 10914)
# ('Z', 'r4_', 'der', 10918)
# ('F', 'r4_', 'den grauen', 10918)
# ('Y', 'r4_', 'der braune Stein', 10919)
# ('Y', 'r4_', 'den braunen Stein', 10925)
# ('U', 'r4_', 'der gelbe', 10925)
# ('U', 'r4_', 'er', 10925)
# ('U', 'r4_', 'er', 10925)
# ('Y', 'r4_', 'dem braunen', 10925)
# ('N', 'r4_', 'der <v="lila">lilane</v> Stein', 10927)
# ('N', 'r4_', 'ihn', 10927)
# ('U', 'r4_', 'dem gelben', 10927)
# ('Y', 'r4_', 'dem braunen', 10927)
# ('N', 'r4_', 'dem <v="lila">lilanen</v> Stein', 10930)
# ('V', 'r4_', 'de:r blaue Winkel', 10930)
# ('T', 'r4_', 'das grüne $T', 10934)
# ('V', 'r4_', 'dem Winkel', 10934)
# ('U', 'r4_1_1_b', 'das gelbe $C', 9618)
# ('U', 'r4_1_1_b', 'dem gelben Stein', 10511)
# ('U', 'r4_1_1_b', 'dieses . $C', 10514)
# ('F', 'r4_1_1_b', 'der graue Stein', 10526)
# ('V', 'r4_1_1_b', 'dieser: Winkel', 10533)
# ('U', 'r4_1_1_b', 'dem gelben Stein', 10535)
# ('U', 'r4_1_1_b', 'dem gelben Stein', 10538)
# ('U', 'r4_1_1_b', 'es', 10538)
# ('V', 'r4_1_1_b', 'der blaue Winkel', 10541)
# ('V', 'r4_1_1_b', 'er', 10546)
# ('F', 'r4_1_1_b', 'dem grauen Stein', 10552)
# ('I', 'r4_1_1_b', 'die {F äh} Gerade', 10552)
# ('F', 'r4_1_1_b', 'er', 10554)
# ('V', 'r4_1_1_b', 'den Winkel', 10559)
# ('L', 'r4_1_1_b', 'der <v="orange">orangene</v> Winkel', 10559)
# ('L', 'r4_1_1_b', '(des {F äh} + (des + (des + (des + (des + (des {F ähm} + <v="orangen">orangenen</v> Winkels))))))', 10565)
# ('T', 'r4_1_1_b', 'das grüne $T', 10565)
# ('T', 'r4_1_1_b', '(der + (des + (der .. + das $T)))', 10569)
# ('T', 'r4_1_1_b', 'das', 10572)
# ('L', 'r4_1_1_b', 'dem', 10572)
# ('Z', 'r4_1_1_b', 'den Stein', 10580)
# ('Z', 'r4_1_1_b', 'den', 10580)
# ('Z', 'r4_1_1_b', 'diesen . schönen petrolfarbenen', 10580)
# ('Z', 'r4_1_1_b', 'Der', 10582)
# ('T', 'r4_1_1_b', 'den grünen Stein', 10582)
# ('N', 'r4_1_1_b', 'der: <v="lila">lilane</v> Stein', 10588)
# ('N', 'r4_1_1_b', 'Der', 10593)
# ('I', 'r4_1_1_b', 'der blaue Balken', 10602)
# ('N', 'r4_1_1_b', 'den Lilanen', 10607)
# ('Z', 'r4_1_1_b', 'den petrolfarbenen', 10618)
# ('P', 'r4_1_1_b', 'der <v="rosa">rosane</v> Stein', 10618)
# ('X', 'r4_1_1_b', 'das Kreuz', 10634)
# ('X', 'r4_1_1_b', 'er', 10636)
# ('T', 'r4_1_1_b', 'der grüne Stein', 10640)
# ('T', 'r4_1_1_b', 'er', 10646)
# ('Y', 'r4_1_1_b', 'der braune', 10655)
# ('Z', 'r4_1_1_s', 'petrolfarbene $Z', 9601)
# ('L', 'r4_1_1_s', 'orange $L', 9603)
# ('W', 'r4_1_1_s', 'dieses hellgrüne $M', 9603)
# ('N', 'r4_1_2_b', 'dem: ... <v="lila">lilanen</v> . Stein', 10672)
# ('N', 'r4_1_2_b', 'der-', 10677)
# ('U', 'r4_1_2_b', 'der gelbe Stein', 10680)
# ('Y', 'r4_1_2_b', 'der braune Stein', 10684)
# ('Y', 'r4_1_2_b', 'er', 10692)
# ('F', 'r4_1_2_b', 'dieses graue ... Gebilde', 10698)
# ('N', 'r4_1_2_b', 'dem <v="lila">lilanen</v>', 10704)
# ('F', 'r4_1_2_b', 'dem Grauen', 10708)
# ('X', 'r4_1_2_b', 'das rote Kreuz', 10708)
# ('P', 'r4_1_2_b', 'der {F ähm:} <v="rosa">rosane</v> Stein', 10712)
# ('Y', 'r4_1_2_b', 'dem Braunen', 10719)
# ('X', 'r4_1_2_b', 'dem Kreuz) kommt jetzt <ref id="T" piece="target"> das $T', 10735)
# ('I', 'r4_1_2_b', 'der blaue Balken', 10741)
# ('P', 'r4_1_2_b', 'den {F ähm} ... <v="orange">rosanen</v>', 10745)
# ('P', 'r4_1_2_b', 'den <v="orange">rosanen</v> Stein', 10745)
# ('Z', 'r4_1_2_b', '(dieses + dieses $Z)', 10745)
# ('T', 'r4_1_2_b', 'das $T', 10761)
# ('L', 'r4_1_2_b', '(der + der) <v="orange">orangene</v> Winkel', 10761)
# ('X', 'r4_1_2_b', 'das Kreuz', 10772)
# ('V', 'r4_1_2_b', 'der blaue Winkel', 10772)
# ('V', 'r4_1_2_b', 'er', 10774)
# ('V', 'r4_1_2_b', '(dieses {F äh:} ... + dieser) Stein', 10776)
# ('X', 'r4_1_2_b', 'dem Kreuz', 10776)
# ('U', 'r4_1_2_s', 'dieses gelbe $C', 9676)
# ('X', 'r4_1_2_s', 'das rote Kreuz', 9676)
# ('F', 'r4_1_2_s', 'dieses . graue . $L', 9676)
# ('Y', 'r4_1_3_b', 'den braunen Stein', 10802)
# ('U', 'r4_1_3_b', 'der gelbe Stein', 10810)
# ('Y', 'r4_1_3_b', 'den braunen Stein', 10814)
# ('Y', 'r4_1_3_b', 'er', 10814)
# ('W', 'r4_1_3_b', '(der + (das + das + das) grüne $M)', 10823)
# ('W', 'r4_1_3_b', 'es', 10827)
# ('W', 'r4_1_3_b', 'dieses Treppchen', 10827)
# ('Y', 'r4_1_3_b', 'braunen Stein', 10827)
# ('U', 'r4_1_3_b', 'dem gelben Stein', 10827)
# ('X', 'r4_1_3_b', 'das Kreuz', 10835)
# ('W', 'r4_1_3_b', 'dem Grünen', 10835)
# ('F', 'r4_1_3_b', 'Der graue Stein', 10840)
# ('X', 'r4_1_3_b', 'das Kreuz', 10846)
# ('V', 'r4_1_3_b', 'Der blaue Winkel', 10850)
# ('F', 'r4_1_3_b', 'den grauen Stein', 10850)
# ('N', 'r4_1_3_b', 'Der <v="lila">lilane</v> Stein', 10854)
# ('V', 'r4_1_3_b', 'den blauen Winkel', 10859)
# ('P', 'r4_1_3_b', 'der pinke Stein', 10867)
# ('P', 'r4_1_3_b', 'der <v="rosa">rosane</v> Stein', 10867)
# ('N', 'r4_1_3_b', 'den . <v="lila">lilanen</v>', 10867)
# ('T', 'r4_1_3_b', 'Das grüne $T', 10870)
# ('N', 'r4_1_3_b', '<v="lila">lilanen</v>', 10872)
# ('N', 'r4_1_3_b', 'er', 10872)
# ('P', 'r4_1_3_b', 'dem . <v="rosa">rosanen</v>', 10872)
# ('Z', 'r4_1_3_b', '(dieses + dieses) .. $Z', 10875)
# ('T', 'r4_1_3_b', 'den grünen', 10875)
# ('N', 'r4_1_3_b', 'den {F äh:m:} <v="lila">lilanen</v> Stein', 10875)
# ('Z', 'r4_1_3_b', 'dem $Z', 10875)
# ('V', 'r4_1_3_b', '(der {F äh:m:} + der) + der) Winkel', 10880)
# ('T', 'r4_1_3_b', 'den grünen', 10880)
# ('I', 'r4_1_3_b', 'der blaue Balken', 10882)
# ('V', 'r4_1_3_b', 'den Winkel', 10882)
# ('L', 'r4_1_3_b', 'das', 10882)
# ('Y', 'r4_1_3_s', 'den Braunen', 9737)
# ('Y', 'r4_1_3_s', 'Diesen', 9739)
# ('T', 'r4_1_3_s', 'das T:', 9739)
# ('V', 'r4_1_3_s', '(Dieses .. + diesen) Kanten', 9743)
# ('V', 'r4_1_3_s', 'diesen Winkel', 9743)
# ('W', 'r4_1_4_b', 'das grüne $M', 10938)
# ('W', 'r4_1_4_b', 'es', 10938)
# ('U', 'r4_1_4_b', 'den gelben', 10938)
# ('X', 'r4_1_4_b', 'das {F äh:} Kreuz', 10940)
# ('N', 'r4_1_4_b', '<v="lila">lilanen</v>', 10940)
# ('X', 'r4_1_4_b', 'das Kreuz', 10940)
# ('I', 'r4_1_4_b', 'der  .. Balken', 10940)
# ('I', 'r4_1_4_s', 'den langen blauen', 9794)
# ('N', 'r4_1_4_s', 'den <v="lila">lilanen</v>', 9794)
# ('P', 'r4_1_4_s', 'den rosanen', 9794)
# ('U', 'r4_1_5_b', 'dem: {F äh:m:} gelben Stein', 10954)
# ('V', 'r4_1_5_b', 'der blaue Winkel', 10956)
# ('V', 'r4_1_5_b', 'das', 10965)
# ('U', 'r4_1_5_b', 'den (ge- + gelben)', 10967)
# ('F', 'r4_1_5_b', 'der graue', 10967)
# ('U', 'r4_1_5_b', 'dem gelben', 10973)
# ('W', 'r4_1_5_b', '(der + das) grüne $M', 10977)
# ('U', 'r4_1_5_b', 'den gelben', 10977)
# ('F', 'r4_1_5_b', 'dem', 10977)
# ('T', 'r4_1_5_b', 'das grüne $T', 10980)
# ('W', 'r4_1_5_b', '$M', 10980)
# ('U', 'r4_1_5_b', 'das gelbe', 10980)
# ('T', 'r4_1_5_b', 'dem grünen $L', 10983)
# ('N', 'r4_1_5_b', 'der <v="lila">lilane</v> Stein', 10983)
# ('X', 'r4_1_5_b', 'das Kreuz', 10988)
# ('Y', 'r4_1_5_b', 'der braune Stein', 10994)
# ('Y', 'r4_1_5_b', 'er', 10994)
# ('X', 'r4_1_5_b', 'das Kreuz', 10994)
# ('N', 'r4_1_5_b', 'er', 10994)
# ('N', 'r4_1_5_b', 'dem <v="lila">lilanen</v>', 10994)
# ('I', 'r4_1_5_b', 'der blaue Balken', 10996)
# ('T', 'r4_1_5_b', 'grünem $T', 10996)
# ('Y', 'r4_1_5_b', '(blau {F äh} + braunem) <v="Ding"> Dingens</v>', 10996)
# ('I', 'r4_1_5_b', 'der', 10999)
# ('I', 'r4_1_5_b', 'den', 10999)
# ('Z', 'r4_1_5_b', '(der + dieser) . $Z Stein', 11004)
# ('Z', 'r4_1_5_b', 'er', 11006)
# ('Z', 'r4_1_5_b', 'er', 11008)
# ('X', 'r4_1_5_b', 'dem Kreuz', 11008)
# ('P', 'r4_1_5_b', 'der . <v="rosa">rosane</v> Stein', 11011)
# ('P', 'r4_1_5_b', 'er', 11014)
# ('X', 'r4_1_5_s', 'das Kreuz', 9816)
# ('L', 'r4_1_5_s', 'das orange $L', 9818)
# ('U', 'r4_1_5_s', 'das gelbe $C', 9818)
# ('X', 'r4_1_6_b', 'das {F äh:m:} Kreuz', 11028)
# ('X', 'r4_1_6_b', 'es', 11032)
# ('X', 'r4_1_6_b', 'es', 11032)
# ('X', 'r4_1_6_b', 'dies rote Kreuz', 11037)
# ('P', 'r4_1_6_b', '(der + der) <v="rosa">rosane</v> Stein', 11037)
# ('X', 'r4_1_6_b', 'das Kreuz', 11042)
# ('X', 'r4_1_6_b', 'das {F äh:} Kreuz', 11045)
# ('U', 'r4_1_6_b', 'der gelbe Stein', 11045)
# ('L', 'r4_1_6_b', 'der <v="orange">orangene</v> Winkel', 11049)
# ('U', 'r4_1_6_b', 'den gelben', 11052)
# ('I', 'r4_1_6_b', 'der blaue Balken', 11056)
# ('U', 'r4_1_6_b', 'den gelben', 11056)
# ('L', 'r4_1_6_b', 'den', 11056)
# ('V', 'r4_1_6_b', 'de:r blaue Winkel', 11059)
# ('V', 'r4_1_6_b', 'er', 11059)
# ('I', 'r4_1_6_b', 'den {F ähm} ... blauen', 11059)
# ('I', 'r4_1_6_b', 'der', 11059)
# ('N', 'r4_1_6_b', 'der <v="lila">lilane</v> Stein', 11069)
# ('N', 'r4_1_6_b', 'er', 11069)
# ('V', 'r4_1_6_b', 'blauen Winkel', 11069)
# ('N', 'r4_1_6_b', 'der', 11073)
# ('T', 'r4_1_6_b', 'das grüne $T', 11076)
# ('Y', 'r4_1_6_b', 'der braune Stein', 11079)
# ('Y', 'r4_1_6_b', 'er', 11079)
# ('V', 'r4_1_6_b', 'Winkel', 11079)
# ('Y', 'r4_1_6_b', 'der braune Stein', 11080)
# ('Y', 'r4_1_6_b', 'er', 11080)
# ('V', 'r4_1_6_b', 'Winkel', 11080)
# ('Z', 'r4_1_6_b', 'der $Z Stein', 11084)
# ('Y', 'r4_1_6_b', 'den braunen', 11089)
# ('F', 'r4_1_6_b', 'der graue', 11091)
# ('P', 'r4_1_6_b', '(dieser + dieser) . pinke', 11095)
# ('P', 'r4_1_6_b', 'er', 11098)
# ('T', 'r4_1_6_s', 'das grüne $T', 9848)
# ('W', 'r4_1_6_s', 'das $M', 9848)
# ('Y', 'r4_1_6_s', 'dieses braune', 9848)
# ('W', 'r4_2_10_b', '(den + dieses) grüne $M', 10162)
# ('X', 'r4_2_10_b', 'das Kreuz', 10168)
# ('X', 'r4_2_10_b', 'es', 10169)
# ('V', 'r4_2_10_b', 'den Winkel', 10169)
# ('Z', 'r4_2_10_b', 'das .. $Z', 10171)
# ('Z', 'r4_2_10_b', 'es', 10173)
# ('Z', 'r4_2_10_b', 'es', 10173)
# ('V', 'r4_2_10_b', 'dem rechten Winkel', 10177)
# ('V', 'r4_2_10_b', 'es', 10177)
# ('Y', 'r4_2_10_b', 'den braunen Stein', 10181)
# ('Y', 'r4_2_10_b', 'den', 10183)
# ('Y', 'r4_2_10_b', 'ihn', 10187)
# ('I', 'r4_2_10_b', 'den langen blauen Stab', 10191)
# ('I', 'r4_2_10_b', 'ihn', 10191)
# ('X', 'r4_2_10_b', 'das .. rote Kreuz', 10191)
# ('W', 'r4_2_10_b', 'grüne $M', 10191)
# ('T', 'r4_2_10_b', 'das $T', 10195)
# ('T', 'r4_2_10_b', 'es', 10197)
# ('T', 'r4_2_10_b', 'es', 10197)
# ('I', 'r4_2_10_b', 'den blauen Stab', 10197)
# ('I', 'r4_2_10_b', 'den {F äh} blauen Winkel', 10203)
# ('V', 'r4_2_10_b', 'ihn', 10216)
# ('V', 'r4_2_10_b', 'ihn', 10218)
# ('Y', 'r4_2_10_b', 'den braunen Stein', 10218)
# ('V', 'r4_2_10_b', 'ihm', 10218)
# ('T', 'r4_2_10_b', 'dem $T', 10218)
# ('U', 'r4_2_10_b', 'das gelbe $C', 10222)
# ('U', 'r4_2_10_b', 'es', 10226)
# ('V', 'r4_2_10_b', 'den blauen Winkel', 10232)
# ('F', 'r4_2_10_b', 'den grauen Stein', 10236)
# ('F', 'r4_2_10_b', 'den', 10236)
# ('F', 'r4_2_10_b', 'ihn', 10238)
# ('U', 'r4_2_10_b', 'das $C', 10238)
# ('N', 'r4_2_10_b', 'den . lilafarbenen Stein', 10243)
# ('N', 'r4_2_10_b', 'es', 10252)
# ('N', 'r4_2_10_b', 'es', 10252)
# ('W', 'r4_2_10_b', 'dem $M', 10254)
# ('L', 'r4_2_10_b', 'den <v="orangen">orangenen</v> . Winkel', 10258)
# ('I', 'r4_2_10_b', 'den blauen', 10264)
# ('P', 'r4_2_10_b', 'das rosa Teil', 10267)
# ('V', 'r4_2_10_b', 'den blauen', 11216)
# ('L', 'r4_2_10_s', '(den + den) {F äh} . <v="orange">rosanen</v> Stein', 11196)
# ('X', 'r4_2_10_s', 'das Kreuz', 11202)
# ('X', 'r4_2_11_b', 'das Kreuz', 10290)
# ('X', 'r4_2_11_b', 'es', 10293)
# ('N', 'r4_2_11_b', 'das lila Teil', 10296)
# ('N', 'r4_2_11_b', 'es', 10296)
# ('N', 'r4_2_11_b', 'es', 10300)
# ('X', 'r4_2_11_b', 'das Kreuz', 10300)
# ('Y', 'r4_2_11_b', 'den braunen', 10304)
# ('Y', 'r4_2_11_b', 'er', 10306)
# ('P', 'r4_2_11_b', 'den <v="rosa">rosanen</v> Stein', 10311)
# ('X', 'r4_2_11_b', 'des Kreuzes', 10320)
# ('Z', 'r4_2_11_b', '(den petrolfarbenen + das petrolfarbene) $Z', 10323)
# ('Z', 'r4_2_11_b', 'das', 10323)
# ('Z', 'r4_2_11_b', 'es', 10328)
# ('W', 'r4_2_11_b', 'das hellgrüne $M', 10331)
# ('W', 'r4_2_11_b', 'es', 10333)
# ('W', 'r4_2_11_b', 'einem $W', 10333)
# ('W', 'r4_2_11_b', 'es', 10333)
# ('W', 'r4_2_11_s', 'diesen ... hellgrüne $M', 11230)
# ('P', 'r4_2_11_s', 'den rosanen', 11232)
# ('X', 'r4_2_11_s', 'das Kreuz', 11234)
# ('I', 'r4_2_12_b', 'den langen blauen', 10354)
# ('U', 'r4_2_12_b', 'das . gelbe $C', 10360)
# ('I', 'r4_2_12_b', 'den . blauen', 10370)
# ('X', 'r4_2_12_b', 'das rote Kreuz', 10373)
# ('N', 'r4_2_12_b', 'den <v="lila">lilanen</v> Stein', 10377)
# ('I', 'r4_2_12_b', 'dem blauen', 10379)
# ('I', 'r4_2_12_b', 'blau', 10379)
# ('X', 'r4_2_12_b', 'roten ... Kreuz', 10379)
# ('F', 'r4_2_12_b', 'den grauen Stein', 10382)
# ('W', 'r4_2_12_b', 'das . hellgrüne $M', 10389)
# ('W', 'r4_2_12_b', 'es', 10389)
# ('W', 'r4_2_12_b', 'es', 10393)
# ('W', 'r4_2_12_b', 'das Treppchen', 10395)
# ('W', 'r4_2_12_b', 'diese $M-Spitze', 10395)
# ('N', 'r4_2_12_b', 'des lila Steines', 10395)
# ('T', 'r4_2_12_b', 'das $T', 10398)
# ('T', 'r4_2_12_b', 'es', 10398)
# ('Y', 'r4_2_12_b', 'den braunen Stein', 10400)
# ('Y', 'r4_2_12_b', 'den', 10400)
# ('W', 'r4_2_12_s', 'dieses grüne $M', 11246)
# ('I', 'r4_2_12_s', 'den blauen Balken', 11248)
# ('I', 'r4_2_12_s', 'den langen', 11248)
# ('I', 'r4_2_12_s', 'das .. graue', 11248)
# ('V', 'r4_2_13_b', 'der Winkel', 10429)
# ('V', 'r4_2_13_b', 'den blauen Winkel', 10431)
# ('V', 'r4_2_13_b', 'den', 10431)
# ('F', 'r4_2_13_b', 'den grauen Stein', 10439)
# ('N', 'r4_2_13_b', 'den <v="lila">lilanen</v> Stein', 10445)
# ('N', 'r4_2_13_b', 'ein Teil', 10447)
# ('N', 'r4_2_13_b', 'er', 10447)
# ('Z', 'r4_2_13_b', '(den + den) $Z-Stein', 10449)
# ('N', 'r4_2_13_b', 'den lila Stein', 10449)
# ('T', 'r4_2_13_b', 'das $T', 10455)
# ('L', 'r4_2_13_b', 'den <v="orangen">orangenen</v> Stein', 10461)
# ('T', 'r4_2_13_b', 'des $Ts', 10461)
# ('I', 'r4_2_13_b', 'den langen blauen Stein', 10463)
# ('L', 'r4_2_13_b', 'den . <v="orangen">orangenen</v> Winkel', 10463)
# ('P', 'r4_2_13_b', 'den rosa Stein', 10468)
# ('X', 'r4_2_13_b', 'das rote Kreuz', 10472)
# ('X', 'r4_2_13_b', 'es', 10472)
# ('W', 'r4_2_13_b', 'das grüne $M', 10475)
# ('Y', 'r4_2_13_b', 'den braunen Stein', 10485)
# ('U', 'r4_2_13_b', 'den gelben Stein', 10500)
# ('U', 'r4_2_13_b', 'er', 10500)
# ('N', 'r4_2_13_s', 'den lilanen', 11260)
# ('U', 'r4_2_13_s', 'das gelbe $C', 11264)
# ('W', 'r4_2_13_s', 'das grüne $M', 11266)
# ('U', 'r4_2_7_b', 'gelbe Stein', 9905)
# ('U', 'r4_2_7_b', 'da drauf', 9911)
# ('U', 'r4_2_7_b', 'darein', 9911)
# ('X', 'r4_2_7_b', 'rote Kreuz', 9911)
# ('T', 'r4_2_7_b', 'das  . große grüne $T', 9913)
# ('X', 'r4_2_7_b', 'das Kreuz', 9913)
# ('T', 'r4_2_7_b', 'drauf', 9915)
# ('Z', 'r4_2_7_b', '(das $C {F äh} + das $Z)', 9919)
# ('N', 'r4_2_7_b', 'diesen <v="lila">lilanen</v> Stein', 9928)
# ('T', 'r4_2_7_b', 'das $T', 9930)
# ('P', 'r4_2_7_b', 'den <v="orange">rosanen</v> Stein', 9935)
# ('P', 'r4_2_7_b', 'es', 9935)
# ('N', 'r4_2_7_b', 'dem <v="lila">lilanen</v> Stein', 9935)
# ('W', 'r4_2_7_b', 'das . $M', 9939)
# ('W', 'r4_2_7_b', 'diese Treppe', 9939)
# ('W', 'r4_2_7_b', 'es', 9939)
# ('F', 'r4_2_7_b', 'den grauen Stein', 9943)
# ('P', 'r4_2_7_b', 'rosa', 9945)
# ('W', 'r4_2_7_b', 'hellgrün', 9945)
# ('Y', 'r4_2_7_b', 'den braunen Stein', 9947)
# ('F', 'r4_2_7_b', 'dem grauen', 9949)
# ('I', 'r4_2_7_b', 'den langen blauen', 9955)
# ('L', 'r4_2_7_b', 'das orange', 9960)
# ('L', 'r4_2_7_b', 'es', 9960)
# ('L', 'r4_2_7_b', 'es', 9960)
# ('L', 'r4_2_7_b', 'es', 9960)
# ('L', 'r4_2_7_b', 'die', 9960)
# ('L', 'r4_2_7_b', 'den', 9960)
# ('P', 'r4_2_7_b', 'dieser', 11126)
# ('Y', 'r4_2_7_b', 'dieser', 11130)
# ('U', 'r4_2_7_s', 'das $C', 9888)
# ('Y', 'r4_2_7_s', 'das', 9895)
# ('U', 'r4_2_7_s', 'gelben Stein', 11104)
# ('P', 'r4_2_7_s', 'den rosanen', 11109)
# ('Y', 'r4_2_7_s', 'den {F äh:} braunen', 11111)
# ('I', 'r4_2_8_b', 'den großen langen blauen', 9984)
# ('I', 'r4_2_8_b', 'ihn', 9984)
# ('V', 'r4_2_8_b', 'er', 9994)
# ('Y', 'r4_2_8_b', 'den braunen', 10007)
# ('Y', 'r4_2_8_b', 'das', 10009)
# ('Y', 'r4_2_8_b', 'es', 10011)
# ('P', 'r4_2_8_b', 'den <v="rosa">rosanen</v>', 10015)
# ('P', 'r4_2_8_b', 'den', 10015)
# ('P', 'r4_2_8_b', 'den', 10017)
# ('V', 'r4_2_8_b', 'den Winkel', 10017)
# ('X', 'r4_2_8_b', 'das Kreuz', 10021)
# ('X', 'r4_2_8_b', 'das Kreuz', 10021)
# ('P', 'r4_2_8_b', 'dem <v="rosa">rosanen</v>', 10021)
# ('U', 'r4_2_8_b', 'das .. $C', 10024)
# ('U', 'r4_2_8_b', 'das $C', 10024)
# ('X', 'r4_2_8_b', 'das Kreuz', 10024)
# ('T', 'r4_2_8_b', 'das  . ($T . + das grüne $T)', 10026)
# ('T', 'r4_2_8_b', 'es', 10026)
# ('Z', 'r4_2_8_b', 'dieses {F äh:} {ja} petrolfarbene $Z', 10034)
# ...
# ('L', 'r8_1_6_b', 'dem <v="orangen">orangenen</v>', 4595)
# ('F', 'r8_1_6_b', 'das Element', 4601)
# ('P', 'r8_1_6_b', 'diesen rosa Bauchstein', 4608)
# ('W', 'r8_1_6_b', 'das Element', 4624)
# ('N', 'r8_1_6_b', 'das Element', 4642)
# ('N', 'r8_1_6_b', 'das', 4644)
# ('T', 'r8_1_6_b', 'das $T', 4660)
# ('T', 'r8_1_6_b', 'es', 4663)
# ('Z', 'r8_1_6_b', 'das $Z', 4670)
# ('Z', 'r8_1_6_b', 'es', 4674)
# ('T', 'r8_1_6_b', 'das $T', 4683)
# ('X', 'r8_1_6_b', 'Das rote Kreuz', 4685)
# ('U', 'r8_1_6_b', 'das $U', 4688)
# ('V', 'r8_1_6_s', 'dieses . (<p="blaue">b-</p> + blaue) $L', 2652)
# ('L', 'r8_1_6_s', 'das orange $L', 2654)
# ('L', 'r8_1_7_b', 'Das $L', 4718)
# ('L', 'r8_1_7_b', 'das andere $L', 4724)
# ('V', 'r8_1_7_b', 'das', 4733)
# ('V', 'r8_1_7_b', 'das', 4735)
# ('V', 'r8_1_7_b', 'es', 4738)
# ('N', 'r8_1_7_b', 'das $Z', 4742)
# ('N', 'r8_1_7_b', 'Das Kleine', 4744)
# ('N', 'r8_1_7_b', 'Das', 4746)
# ('W', 'r8_1_7_b', 'das grüne $W', 4759)
# ('L', 'r8_1_7_s', 'orange $L', 2712)
# ('Y', 'r8_1_8_b', '<v="das">\'s</v>', 2750)
# ('Y', 'r8_1_8_b', 'dem braunen Teil', 4789)
# ('W', 'r8_1_8_b', 'das grüne $W', 4800)
# ('X', 'r8_1_8_b', 'das rote <p>d-</p> Kreuz', 4819)
# ('W', 'r8_1_8_b', 'dieses $W', 4821)
# ('P', 'r8_1_8_b', 'dieser rosa Bauch', 4825)
# ('N', 'r8_1_8_b', 'das kleinere $Z', 4839)
# ('N', 'r8_1_8_b', 'das andere $Z', 4859)
# ('N', 'r8_1_8_b', 'Das', 4861)
# ('Z', 'r8_1_8_b', 'dieses $Z', 4862)
# ('X', 'r8_1_8_b', 'das Rote', 4862)
# ('T', 'r8_1_8_b', 'das grüne $T', 4871)
# ('I', 'r8_1_8_b', 'das blaue längliche Element', 4879)
# ('I', 'r8_1_8_b', 'Das', 4881)
# ('I', 'r8_1_8_b', 'Das', 4882)
# ('L', 'r8_1_8_b', 'das rechte orange $L', 4889)
# ('L', 'r8_1_8_b', 'Das', 4891)
# ('L', 'r8_1_8_b', 'das', 4892)
# ('L', 'r8_1_8_b', 'das Element', 4896)
# ('T', 'r8_1_8_b', 'das $T', 4902)
# ('V', 'r8_1_8_b', 'das Element', 4908)
# ('F', 'r8_1_8_b', '(<p="dieses">die-</p> (genau) + das) Element', 4919)
# ('F', 'r8_1_8_b', 'es', 4925)
# ('V', 'r8_1_8_b', 'dem Blauen', 4928)
# ('U', 'r8_1_8_b', 'das $U', 4944)
# ('F', 'r8_1_8_b', 'dieses Element', 4945)
# ('F', 'r8_1_8_b', 'dieses Element', 4955)
# ('F', 'r8_1_8_s', 'das {F äh} Graue', 2741)
# ('Y', 'r8_1_8_s', 'das . braune $T', 2741)
# ('X', 'r8_1_9_b', 'das rote $T', 2837)
# ('X', 'r8_1_9_b', 'das Plus', 2837)
# ('Y', 'r8_1_9_b', 'Das kleine <p="braune">braun-</p>', 2859)
# ('W', 'r8_1_9_b', 'das grüne $W', 4984)
# ('W', 'r8_1_9_b', 'es', 4989)
# ('X', 'r8_1_9_b', 'das rote Kreuz', 4998)
# ('P', 'r8_1_9_b', 'Das bauchige Element', 5014)
# ('X', 'r8_1_9_b', 'dem Roten', 5015)
# ('U', 'r8_1_9_b', 'das gelbe $U', 5028)
# ('X', 'r8_1_9_b', 'dies rote $T', 5030)
# ('X', 'r8_1_9_b', 'Plus', 5036)
# ('U', 'r8_1_9_b', 'das Gelbe', 5043)
# ('I', 'r8_1_9_b', 'Das längliche blaue Element', 5044)
# ('L', 'r8_1_9_b', '(<p="orange">o-</p> {F ähm} + <v="orange">orangene</v>) $L', 5049)
# ('V', 'r8_1_9_b', 'das blaue andere $L', 5061)
# ('V', 'r8_1_9_b', 'den langen blauen Streifen', 5063)
# ('N', 'r8_1_9_b', 'das $Z <p="und">u-</p>', 5072)
# ('N', 'r8_1_9_b', 'Das', 5075)
# ('N', 'r8_1_9_b', 'es', 5078)
# ('N', 'r8_1_9_b', 'es', 5080)
# ('T', 'r8_1_9_b', 'das . grüne $T', 5084)
# ('Y', 'r8_1_9_b', 'das braune kleine $T', 5092)
# ('Y', 'r8_1_9_b', 'Das', 5096)
# ('Y', 'r8_1_9_b', 'es', 5111)
# ('Y', 'r8_1_9_b', 'es', 5112)
# ('Y', 'r8_1_9_b', 'es', 5114)
# ('Y', 'r8_1_9_b', 'es', 5116)
# ('Y', 'r8_1_9_b', 'es', 5118)
# ('V', 'r8_1_9_b', 'das blaue Element', 5118)
# ('Z', 'r8_1_9_b', 'dieses . $Z', 5123)
# ('Y', 'r8_1_9_b', 'das', 5132)
# ('Y', 'r8_1_9_b', 'das kleine braune $T', 5132)
# ('F', 'r8_1_9_b', 'es', 5140)
# ('W', 'r8_1_9_s', 'Das grüne $W', 2810)
# ('L', 'r8_1_9_s', '(das + diesen) (<p="orangen">ora-</p> + <v="rosa">rosanen</v>) <unsure>Bauch</unsure>', 2810)
# ('I', 'r8_1_9_s', 'das Blaue', 2812)
# ('W', 'r8_2_10_b', 'dieses {F äh} grüne $M', 2902)
# ('W', 'r8_2_10_b', '$W', 2904)
# ('W', 'r8_2_10_b', 'das', 2907)
# ('W', 'r8_2_10_b', 'es', 2910)
# ('N', 'r8_2_10_b', 'das <breathing/> <v="lila">lilane</v> $Z', 2911)
# ('N', 'r8_2_10_b', 'das', 2914)
# ('W', 'r8_2_10_b', 'es', 2925)
# ('N', 'r8_2_10_b', '(des $N + des Ns)', 2925)
# ('I', 'r8_2_10_b', '(das . <p="blaue">b-</p> + das blaue) Anfangselement', 2937)
# ('N', 'r8_2_10_b', 'das', 2938)
# ('W', 'r8_2_10_b', 'das Grüne', 2938)
# ('N', 'r8_2_10_b', 'das Lilane', 2938)
# ('P', 'r8_2_10_b', 'das <v="rosa">rosane</v> Element', 2946)
# ('P', 'r8_2_10_b', 'das', 2951)
# ('P', 'r8_2_10_b', 'es', 2959)
# ('N', 'r8_2_10_b', 'das <v="Lila">Lilane</v>', 2959)
# ('L', 'r8_2_10_b', 'das orange $L', 2964)
# ('L', 'r8_2_10_b', 'es', 2964)
# ('T', 'r8_2_10_b', 'das $T', 2969)
# ('T', 'r8_2_10_b', 'das Grüne', 2972)
# ('I', 'r8_2_10_b', 'Blaue', 2972)
# ('X', 'r8_2_10_b', 'das {F äh} rote Plus', 2976)
# ('T', 'r8_2_10_b', 'das $T', 2981)
# ('Y', 'r8_2_10_b', 'das Plus', 2982)
# ('Z', 'r8_2_10_b', 'das blaue $Z', 2995)
# ('Y', 'r8_2_10_b', 'das braune Element', 3003)
# ('Y', 'r8_2_10_b', 'Das', 3005)
# ('V', 'r8_2_10_b', 'das blaue Element', 3014)
# ('V', 'r8_2_10_b', 'das', 3017)
# ('T', 'r8_2_10_b', 'das $T', 3026)
# ('F', 'r8_2_10_b', 'das . {F äh} graue Element', 3027)
# ('F', 'r8_2_10_b', 'das', 3035)
# ('U', 'r8_2_10_b', 'das $U', 3045)
# ('I', 'r8_2_10_s', 'das Blaue', 2875)
# ('L', 'r8_2_10_s', 'das .. <v="Orange">Orangene</v> und dann <ref id="T" piece="target"> das . Grüne', 2875)
# ('V', 'r8_2_11_b', 'das . blaue $L', 3073)
# ('I', 'r8_2_11_b', 'das', 3084)
# ('V', 'r8_2_11_b', 'das blaue $L', 3084)
# ('Y', 'r8_2_11_b', 'das braune Element', 3094)
# ('Y', 'r8_2_11_b', 'das', 3100)
# ('V', 'r8_2_11_b', 'das blaue $L', 3100)
# ('P', 'r8_2_11_b', 'das <v="rosa">rosane</v> Element', 3104)
# ('P', 'r8_2_11_b', 'das', 3110)
# ('P', 'r8_2_11_b', 'es', 3113)
# ('Y', 'r8_2_11_b', 'das Braune', 3113)
# ('V', 'r8_2_11_b', 'das Blaue', 3113)
# ('T', 'r8_2_11_b', 'das $T', 3115)
# ('T', 'r8_2_11_b', 'es', 3115)
# ('T', 'r8_2_11_b', 'es', 3115)
# ('X', 'r8_2_11_b', 'das Plus', 3123)
# ('P', 'r8_2_11_b', 'das <v="rosa">rosane</v> Element', 3123)
# ('W', 'r8_2_11_b', 'Diese Treppenstufe', 3127)
# ('U', 'r8_2_11_b', 'das $U', 3129)
# ('X', 'r8_2_11_b', 'das Plus', 3134)
# ('Z', 'r8_2_11_b', 'das $Z', 3136)
# ('Z', 'r8_2_11_b', 'Das', 3138)
# ('Z', 'r8_2_11_b', 'das', 3150)
# ('T', 'r8_2_11_b', 'dem $T', 3150)
# ('U', 'r8_2_11_b', 'dem .. $U', 3150)
# ('N', 'r8_2_11_b', 'das: ... <v="lila">lilane</v> $Z', 3153)
# ('N', 'r8_2_11_b', 'das $Z', 3165)
# ('W', 'r8_2_11_b', 'dieses {F äh} grüne $M', 3168)
# ('W', 'r8_2_11_b', 'das', 3170)
# ('N', 'r8_2_11_b', 'das <v="lila">lilane</v> Teil', 3179)
# ('L', 'r8_2_11_b', 'Das $L', 3189)
# ('W', 'r8_2_11_b', 'das Grüne', 3191)
# ('W', 'r8_2_11_b', 'das Grüne', 3191)
# ('F', 'r8_2_11_b', 'das Element', 3196)
# ('L', 'r8_2_11_b', 'das <v="Orange">Orangene</v>', 3202)
# ('T', 'r8_2_11_s', 'das . $T', 3055)
# ('X', 'r8_2_11_s', 'das . Plus', 3055)
# ('N', 'r8_2_11_s', 'das . $N', 3055)
# ('I', 'r8_2_12_b', 'das {F ähm} blaue Element', 3232)
# ('T', 'r8_2_12_b', 'das $T', 3233)
# ('T', 'r8_2_12_b', 'es', 3233)
# ('T', 'r8_2_12_b', 'es', 3240)
# ('T', 'r8_2_12_b', 'es', 3240)
# ('F', 'r8_2_12_b', 'das . graue Element', 3248)
# ('F', 'r8_2_12_b', 'es', 3254)
# ('U', 'r8_2_12_b', 'das $U', 3273)
# ('U', 'r8_2_12_b', 'es', 3273)
# ('U', 'r8_2_12_b', 'es', 3273)
# ('U', 'r8_2_12_b', 'das', 3277)
# ('U', 'r8_2_12_b', 'es', 3279)
# ('V', 'r8_2_12_b', 'Das blaue $L', 3280)
# ('L', 'r8_2_12_b', 'das <v="orange">orangene</v> $L', 3284)
# ('L', 'r8_2_12_b', 'es', 3286)
# ('I', 'r8_2_12_s', 'das Blaue', 3223)
# ('U', 'r8_2_12_s', 'das Gelbe', 3223)
# ('N', 'r8_2_13_b', 'das <v="lila">lilane</v> Element', 3305)
# ('N', 'r8_2_13_b', 'es', 3307)
# ('N', 'r8_2_13_b', 'es', 3309)
# ('N', 'r8_2_13_b', 'es', 3309)
# ('N', 'r8_2_13_b', 'Es', 3315)
# ('N', 'r8_2_13_b', 'es', 3316)
# ('N', 'r8_2_13_b', 'es', 3317)
# ('V', 'r8_2_13_b', 'das blaue $L', 3327)
# ('V', 'r8_2_13_b', 'es', 3327)
# ('P', 'r8_2_13_b', 'das <v="rosa">rosane</v> Element', 3330)
# ('P', 'r8_2_13_b', 'es so dass <ref id="P" piece="target"> es', 3330)
# ('N', 'r8_2_13_b', 'das <v="Lila">Lilane</v>', 3333)
# ('Z', 'r8_2_13_b', 'das ... $Z', 3335)
# ('Z', 'r8_2_13_b', 'es', 3335)
# ('Z', 'r8_2_13_b', 'Das', 3337)
# ('Z', 'r8_2_13_b', 'Das blaue $Z', 3338)
# ('Z', 'r8_2_13_b', 'das', 3342)
# ('N', 'r8_2_13_b', 'das <v="lila">lilane</v> $Z', 3342)
# ('N', 'r8_2_13_b', 'das $Z', 3343)
# ('T', 'r8_2_13_b', 'das $T', 3348)
# ('L', 'r8_2_13_b', 'Das . $L', 3350)
# ('T', 'r8_2_13_b', 'dieses $T', 3355)
# ('V', 'r8_2_13_b', '$L einfach', 3358)
# ('V', 'r8_2_13_b', 'der Blaue', 3358)
# ('I', 'r8_2_13_b', 'der', 3360)
# ('L', 'r8_2_13_b', 'das $L', 3360)
# ('L', 'r8_2_13_b', 'dem $L', 3365)
# ('X', 'r8_2_13_b', 'das Plus', 3371)
# ('X', 'r8_2_13_b', 'das Rote', 3371)
# ('X', 'r8_2_13_b', 'es', 3371)
# ('P', 'r8_2_13_b', 'das <v="rosa">rosane</v> Element', 3371)
# ('F', 'r8_2_13_b', 'das graue Teil', 3375)
# ('F', 'r8_2_13_b', 'es', 3375)
# ('F', 'r8_2_13_b', 'Das graue Element', 3376)
# ('F', 'r8_2_13_b', 'dem grauen Element', 3378)
# ('W', 'r8_2_13_b', 'das . grüne $M', 3385)
# ('W', 'r8_2_13_b', 'es', 3385)
# ('X', 'r8_2_13_b', 'das Plus', 3385)
# ('Y', 'r8_2_13_b', 'das braune Element', 3397)
# ('Y', 'r8_2_13_b', 'es', 3397)
# ('Y', 'r8_2_13_b', 'das', 3400)
# ('W', 'r8_2_13_b', 'des Grünen', 3400)
# ('U', 'r8_2_13_b', 'das gelbe Element', 3408)
# ('W', 'r8_2_13_b', 'das Grüne', 3408)
# ('Y', 'r8_2_13_b', 'das Braune', 3408)
# ('U', 'r8_2_13_b', 'es', 3409)
# ('N,Z', 'r8_2_13_b', 'Die beiden $Zs', 3417)
# ('F', 'r8_2_13_b', 'das graue Element', 3417)
# ('L', 'r8_2_14_b', 'dem <v="orangen">orangenen</v> $L', 3422)
# ('L', 'r8_2_14_b', 'es', 3425)
# ('T', 'r8_2_14_b', 'Das $T', 3429)
# ('L', 'r8_2_14_b', 'das $L', 3429)
# ('I', 'r8_2_14_b', 'den (bau- + blauen) Senkrechten', 3433)
# ('T', 'r8_2_14_b', 'das $T', 3436)
# ('T', 'r8_2_14_b', 'das', 3436)
# ('X', 'r8_2_14_b', 'das Plus', 3444)
# ('X', 'r8_2_14_b', 'es', 3444)
# ('T', 'r8_2_14_b', 'das $T', 3444)
# ('V', 'r8_2_14_b', 'das {F ähm} blaue $L', 3448)
# ('V', 'r8_2_14_b', 'es', 3448)
# ('V', 'r8_2_14_b', 'es', 3451)
# ('X', 'r8_2_14_b', 'das Plus-Zeichen', 3451)
# ('W', 'r8_2_14_b', 'das $M', 3456)
# ('X', 'r8_2_14_b', 'das Plus-Zeichen', 3457)
# ('F', 'r8_2_14_b', 'das graue Element', 3464)
# ('F', 'r8_2_14_b', 'das', 3466)
# ('X', 'r8_2_14_b', 'des Plus-Zeichens', 3466)
# ('P', 'r8_2_14_b', 'das <v="rosa">rosane</v> Element', 3474)
# ('P', 'r8_2_14_b', 'Das', 3475)
# ('P', 'r8_2_14_b', 'es', 3476)
# ('T', 'r8_2_14_b', 'das $T', 3477)
# ('T', 'r8_2_14_b', 'das grüne $T', 3478)
# ('I', 'r8_2_14_b', 'gerade das Bauteil', 3483)
# ('Z', 'r8_2_14_b', 'das $Z', 3484)
# ('P', 'r8_2_14_b', 'dem <v="rosa">rosanen</v> Element', 3486)
# ('Y', 'r8_2_14_b', 'das braune Element', 3492)
# ('Y', 'r8_2_14_b', 'es', 3492)
# ('P', 'r8_2_14_b', 'das <v="rosa">rosane</v> Element', 3494)
# ('Z', 'r8_2_14_b', 'Das $Z', 3499)
# ('F', 'r8_2_14_b', 'das graue Element', 3500)
# ('U', 'r8_2_14_b', 'das $U', 3504)
# ('U', 'r8_2_14_b', 'es', 3504)
# ('U', 'r8_2_15_b', 'das $U', 3538)
# ('P', 'r8_2_15_b', 'das <v="rosa">rosane</v> Element', 3542)
# ('P', 'r8_2_15_b', 'es', 3542)
# ('T', 'r8_2_15_b', 'das $T', 3545)
# ('P', 'r8_2_15_b', 'das <v="rosa">rosane</v> Element', 3548)
# ('Z', 'r8_2_15_b', 'das $Z', 3550)
# ('Z', 'r8_2_15_b', 'es', 3550)
# ('T', 'r8_2_15_b', 'das $T', 3550)
# ('W', 'r8_2_15_b', 'das . $M', 3553)
# ('V', 'r8_2_15_b', 'das $L', 3556)
# ('V', 'r8_2_15_b', 'es', 3556)
# ('V', 'r8_2_15_b', 'Das Blaue', 3557)
# ('V', 'r8_2_15_b', 'Das blaue $L', 3558)
# ('U', 'r8_2_15_s', 'das Gelbe', 3519)
# ('U', 'r8_2_15_s', 'das Gelbe', 5240)
# ('X', 'r8_2_16_b', 'Das Plus-Zeichen', 3588)
# ('X', 'r8_2_16_b', '<v="ein">\'n</v> {F äh} Erste-Hilfe-Rotes-Kreuz', 3588)
# ('N', 'r8_2_16_b', 'das {F ähm} . $Z', 3593)
# ('N', 'r8_2_16_b', 'es', 3593)
# ('N', 'r8_2_16_b', 'das <v="lila">lilane</v> $Z', 3594)
# ('N', 'r8_2_16_b', 'es', 3600)
# ('N', 'r8_2_16_b', 'es', 3600)
# ('N', 'r8_2_16_b', 'das', 3605)
# ('X', 'r8_2_16_b', 'das Kreuz', 3605)
# ('N', 'r8_2_16_b', 'es', 3608)
# ('F', 'r8_2_16_b', 'das .. graue Element', 3617)
# ('F', 'r8_2_16_b', 'das <v="lila">lilane</v> Element', 3623)
# ('F', 'r8_2_16_b', 'es', 3623)
# ('Y', 'r8_2_16_b', 'das braune Element', 3626)
# ('Y', 'r8_2_16_b', 'es', 3626)
# ('Y', 'r8_2_16_b', 'das', 3631)
# ('X', 'r8_2_16_b', 'dem Roten', 3631)
# ('N', 'r8_2_16_b', 'dem <v="Lila">Lilanen</v>', 3631)
# ('F', 'r8_2_16_b', 'dem Grauen', 3631)
# ('W', 'r8_2_16_b', 'das', 3644)
# ('W', 'r8_2_16_b', 'das $M', 3647)
# ('X', 'r8_2_16_s', 'das Rote?', 3572)
# ('X', 'r8_2_16_s', 'das Rote', 5249)
# ('L', 'r8_2_17_b', 'das $L', 3665)
# ('L', 'r8_2_17_b', 'es', 3665)
# ('L', 'r8_2_17_b', 'es', 3665)
# ('F', 'r8_2_17_b', 'das graue Element', 3670)
# ('F', 'r8_2_17_b', 'es', 3670)
# ('F', 'r8_2_17_b', 'es', 3670)
# ('L', 'r8_2_17_b', 'das $L', 3673)
# ('Z', 'r8_2_17_b', 'Das $Z', 3675)
# ('N', 'r8_2_17_b', 'das (<v="Lila><p="Lilane">L-</p></v> {F äh} + <v="Lila>Lilane</v>)', 3675)
# ('N', 'r8_2_17_b', 'Das', 3677)
# ('N', 'r8_2_17_b', 'das', 3677)
# ('T', 'r8_2_17_b', 'das $T', 3680)
# ('N', 'r8_2_17_b', 'das <v="lila">lilane</v> Element', 3682)
# ('X', 'r8_2_17_b', 'das rote Kreuz', 3687)
# ('F', 'r8_2_17_b', 'das graue Element', 3687)
# ('U', 'r8_2_17_b', 'das gelbe $U', 3690)
# ('I', 'r8_2_17_b', 'das $T (dieser Blaue <p="senkrecht">senk-</p>', 3696)
# ('I', 'r8_2_17_b', 'dieser blaue Längliche einfach senkrecht)', 3696)
# ('V', 'r8_2_17_b', 'das blaue $L', 3699)
# ('U', 'r8_2_17_b', 'das:', 3699)
# ('V,L', 'r8_2_17_s', 'Die beiden $Ls', 3656)
# ('Y', 'r8_2_18_b', 'das braune Element', 3722)
# ('Y', 'r8_2_18_b', 'es', 3722)
# ('W', 'r8_2_18_b', 'das .. $M', 3726)
# ('W', 'r8_2_18_b', 'es', 3726)
# ('Y', 'r8_2_18_b', 'das braune Element', 3729)
# ('N', 'r8_2_18_b', 'das <v="lila">lilane</v> $Z', 3732)
# ('N', 'r8_2_18_b', '$Z', 3732)
# ('Y', 'r8_2_18_b', 'das Braune', 3739)
# ('L', 'r8_2_18_b', 'das .. $L', 3741)
# ('L', 'r8_2_18_b', 'Das <v="orange">orangene</v> $L', 3743)
# ('L', 'r8_2_18_b', 'es', 3745)
# ('U', 'r8_2_18_b', 'das $U', 3747)
# ('L', 'r8_2_18_b', 'das $L', 3747)
# ('X', 'r8_2_18_b', 'das <p="Kreuz">Kr-</p>', 3752)
# ('X', 'r8_2_18_b', 'das Kreuz', 3756)
# ('V', 'r8_2_18_b', 'das blaue $L', 3757)
# ('Y', 'r8_2_18_s', 'Das Braune', 3710)
# ('Y', 'r8_2_18_s', 'das braune Element', 5282)
# ('P', 'r8_2_19_b', 'das <v="rosa">rosane</v> Element', 3775)
# ('P', 'r8_2_19_b', 'Das', 3776)
# ('P', 'r8_2_19_b', 'Das', 3777)
# ('P', 'r8_2_19_b', 'es', 3779)
# ('P', 'r8_2_19_b', 'es', 3781)
# ('T', 'r8_2_19_b', 'das ... $T', 3782)
# ('T', 'r8_2_19_b', 'das', 3784)
# ('T', 'r8_2_19_b', 'es', 3788)
# ('T', 'r8_2_19_b', 'es', 3788)
# ('T', 'r8_2_19_b', 'es', 3789)
# ('W', 'r8_2_19_b', 'das ... grüne $W', 3794)
# ('W', 'r8_2_19_b', '$M', 3794)
# ('T', 'r8_2_19_b', 'das $T', 3794)
# ('T', 'r8_2_19_b', 'des $Ts', 3796)
# ('T', 'r8_2_19_b', 'dem $T', 3801)
# ('T', 'r8_2_19_b', 'das $T', 3822)
# ('N', 'r8_2_19_b', 'das <v="lila">lilane</v> $Z', 3831)
# ('N', 'r8_2_19_b', 'es', 3838)
# ('V', 'r8_2_19_s', 'Das {F äh} <v="Rosa">Rosane</v>', 3763)
# ('Y', 'r8_2_20_b', 'das: {F ähm} braune $T', 3850)
# ('Y', 'r8_2_20_b', 'es', 3852)
# ('Y', 'r8_2_20_b', 'es', 3854)
# ('V', 'r8_2_20_b', 'das blaue $L', 3859)
# ('V', 'r8_2_20_b', 'es', 3859)
# ('V', 'r8_2_20_b', 'es', 3859)
# ('Y', 'r8_2_20_b', 'das', 3859)
# ('V', 'r8_2_20_b', 'es', 3866)
# ('I', 'r8_2_20_b', 'das .. blaue Längliche', 3869)
# ('I', 'r8_2_20_b', 'es', 3869)
# ('I', 'r8_2_20_b', 'Das', 3870)
# ('V', 'r8_2_20_b', 'daneben', 3870)
# ('Y', 'r8_2_20_b', 'das Braune', 3875)
# ('W', 'r8_2_20_b', 'das grüne $M', 3888)
# ('W', 'r8_2_20_b', 'es', 3894)
# ('V', 'r8_2_20_b', 'das blaue $L', 3894)
# ('Z', 'r8_2_20_b', 'das blaue $Z', 3901)
# ('Z', 'r8_2_20_b', 'Das blaue $Z', 3903)
# ('Z', 'r8_2_20_b', 'es', 3904)
# ('Z', 'r8_2_20_b', 'dieses', 3906)
# ('F', 'r8_2_20_b', 'Das . graue Element', 3911)
# ('F', 'r8_2_20_b', 'Das', 3912)
# ('Z', 'r8_2_20_b', 'dem blauen $Z', 3912)
# ('N', 'r8_2_20_b', 'das .. <v="lila">lilane</v> $Z', 3921)
# ('F', 'r8_2_20_b', 'das graue Element', 3925)
# ('L', 'r8_2_20_b', 'das ... $L', 3928)
# ('N', 'r8_2_20_b', 'das <p="lila">li-</p>', 3935)
# ('L', 'r8_2_20_b', 'des $Ls', 3936)
# ('N', 'r8_2_20_b', 'des <v="lila">lilanen</v> $Z', 3936)
# ('T', 'r8_2_20_b', 'das .. $T', 3942)
# ('T', 'r8_2_20_b', 'es', 3942)
# ('L', 'r8_2_20_b', 'dem $L', 3942)
# ('W', 'r8_2_20_b', 'dem $M', 3942)
# ('P', 'r8_2_20_b', 'das <v="rosa">rosane</v> Element', 3946)
# ('P', 'r8_2_20_b', 'Das', 3947)
# ('X', 'r8_2_20_b', 'das', 3954)
# ('U', 'r8_2_20_b', '(das blaue {F äh} + das blaue)', 3956)
# ('U', 'r8_2_20_b', 'Das gelbe $U', 3957)
# ('T,Y', 'r8_2_20_s', 'die beiden $Ts', 5310)

# %%
len(test_data)
# Out:
# 0

# %%
from nltk.classify import SklearnClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_fscore_support, classification_report
from random import shuffle
import numpy as np

def trainClassifier(trainData):
    print("Training Classifier...")
    return SklearnClassifier(LinearSVC(loss='squared_hinge')).train(trainData)
    #return SklearnClassifier(LogisticRegression()).train(trainData)
    #return SklearnClassifier(MultinomialNB()).train(trainData)

def predictLabels(reviewSamples, classifier):
    return classifier.classify_many(map(lambda t: t[0], reviewSamples))

def predictLabel(text, classifier):
    return classifier.classify(toFeatureVector(preProcess(text)))

def crossValidate(dataset, folds):
    shuffle(dataset)
    dataset = dataset[:int(len(dataset)/8)] # random 1/8th%
    results = []
    foldSize = int(len(dataset)/folds)+1
    
    for i in range(0,len(dataset),int(foldSize)):
        # insert code here that trains and tests on the 10 folds of data in the dataset
        print("Fold start on items %d - %d" % (i, i+foldSize))
        myTestData = dataset[i:i+foldSize]
        myTrainData = dataset[:i] + dataset[i+foldSize:]
        classifier = trainClassifier(myTrainData)
        y_true = [x[1] for x in myTestData]
        y_pred = predictLabels(myTestData, classifier)
        results.append(precision_recall_fscore_support(y_true, y_pred, average='weighted'))
        print(classification_report(y_true, y_pred))
        
    avgResults = (np.mean([x[0] for x in results]),
                  np.mean([x[1] for x in results]),
                  np.mean([x[2] for x in results]))
    return avgResults

av = crossValidate(train_data, 10)
print(av)
if False:
    cl = trainClassifier(train_data)
    y_true = [x[1] for x in test_data]
    y_pred = predictLabels(test_data, cl)
    print(precision_recall_fscore_support(y_true, y_pred, average='weighted'))
    print(classification_report(y_true, y_pred))
# Out:
# Fold start on items 0 - 35
# Training Classifier...
#               precision    recall  f1-score   support
#
#            F       1.00      0.75      0.86         4
#            I       0.67      1.00      0.80         2
#            N       1.00      0.75      0.86         4
#            P       1.00      0.50      0.67         2
#            T       0.75      0.60      0.67         5
#            U       1.00      1.00      1.00         1
#            V       1.00      0.50      0.67         2
#            W       0.43      1.00      0.60         3
#            X       1.00      0.50      0.67         2
#            Y       0.78      0.88      0.82         8
#            Z       0.50      0.50      0.50         2
#
#     accuracy                           0.74        35
#    macro avg       0.83      0.72      0.74        35
# weighted avg       0.82      0.74      0.75        35
#
# Fold start on items 35 - 70
# Training Classifier...
#               precision    recall  f1-score   support
#
#            F       0.75      0.60      0.67         5
#            I       1.00      1.00      1.00         1
#            L       1.00      0.33      0.50         3
#            N       0.44      1.00      0.62         4
#            P       0.00      0.00      0.00         1
#            T       0.60      0.60      0.60         5
#            U       1.00      0.67      0.80         3
#            V       0.00      0.00      0.00         1
#            W       0.71      0.83      0.77         6
#            X       1.00      1.00      1.00         2
#            Y       1.00      1.00      1.00         3
#            Z       1.00      1.00      1.00         1
#
#     accuracy                           0.71        35
#    macro avg       0.71      0.67      0.66        35
# weighted avg       0.74      0.71      0.69        35
#
# Fold start on items 70 - 105
# Training Classifier...
#               precision    recall  f1-score   support
#
#            F       0.00      0.00      0.00         2
#            I       0.33      1.00      0.50         3
#            L       0.50      0.50      0.50         4
#            N       0.67      0.67      0.67         3
#            P       1.00      1.00      1.00         1
#            T       0.33      0.50      0.40         4
#            U       0.50      1.00      0.67         1
#          UNK       0.00      0.00      0.00         1
#            V       1.00      0.20      0.33         5
#            W       0.67      0.80      0.73         5
#            X       1.00      0.50      0.67         4
#            Y       1.00      0.50      0.67         2
#
#     accuracy                           0.54        35
#    macro avg       0.58      0.56      0.51        35
# weighted avg       0.63      0.54      0.52        35
#
# Fold start on items 105 - 140
# Training Classifier...
#               precision    recall  f1-score   support
#
#            F       1.00      0.67      0.80         3
#            I       1.00      0.67      0.80         3
#            L       1.00      0.25      0.40         4
#            N       0.29      1.00      0.44         2
#            P       1.00      0.50      0.67         2
#            T       0.50      0.67      0.57         3
#            U       1.00      1.00      1.00         2
#            V       1.00      0.50      0.67         2
#            W       0.00      0.00      0.00         1
#            X       1.00      1.00      1.00         4
#            Y       1.00      0.60      0.75         5
#            Z       1.00      0.75      0.86         4
#
#     accuracy                           0.66        35
#    macro avg       0.82      0.63      0.66        35
# weighted avg       0.89      0.66      0.71        35
#
# Fold start on items 140 - 175
# Training Classifier...
#               precision    recall  f1-score   support
#
#            F       0.50      0.33      0.40         3
#            I       0.33      1.00      0.50         1
#            L       0.60      0.75      0.67         4
#            N       0.25      0.50      0.33         2
#            P       1.00      0.67      0.80         3
#            T       1.00      0.57      0.73         7
#            U       0.50      0.50      0.50         2
#            V       1.00      0.25      0.40         4
#            W       0.43      1.00      0.60         3
#            X       1.00      1.00      1.00         2
#            Y       1.00      1.00      1.00         1
#            Z       0.50      0.33      0.40         3
#
#     accuracy                           0.60        35
#    macro avg       0.68      0.66      0.61        35
# weighted avg       0.73      0.60      0.60        35
#
# Fold start on items 175 - 210
# Training Classifier...
#               precision    recall  f1-score   support
#
#            F       1.00      0.33      0.50         3
#            I       0.20      1.00      0.33         1
#            L       0.50      1.00      0.67         4
#            N       1.00      1.00      1.00         1
#            P       1.00      0.50      0.67         2
#            T       1.00      0.60      0.75         5
#            U       1.00      0.67      0.80         6
#            V       1.00      1.00      1.00         2
#            W       0.50      0.67      0.57         3
#            X       1.00      1.00      1.00         1
#            Y       0.50      0.50      0.50         2
#            Z       0.67      0.40      0.50         5
#
#     accuracy                           0.66        35
#    macro avg       0.78      0.72      0.69        35
# weighted avg       0.80      0.66      0.67        35
#
# Fold start on items 210 - 245
# Training Classifier...
#               precision    recall  f1-score   support
#
#            F       0.50      1.00      0.67         1
#            I       0.75      0.38      0.50         8
#            L       0.50      1.00      0.67         1
#            N       0.75      0.60      0.67         5
#            P       1.00      1.00      1.00         2
#            T       0.33      1.00      0.50         1
#            U       0.50      1.00      0.67         1
#            V       0.20      0.50      0.29         2
#            W       0.67      0.67      0.67         6
#            X       1.00      1.00      1.00         2
#            Y       1.00      1.00      1.00         2
#            Z       0.00      0.00      0.00         4
#
#     accuracy                           0.60        35
#    macro avg       0.60      0.76      0.63        35
# weighted avg       0.63      0.60      0.58        35
#
# Fold start on items 245 - 280
# Training Classifier...
#               precision    recall  f1-score   support
#
#            F       0.67      1.00      0.80         2
#            I       0.50      1.00      0.67         1
#            L       0.50      1.00      0.67         2
#            N       0.75      0.50      0.60         6
#            P       1.00      1.00      1.00         3
#            T       1.00      0.75      0.86         4
#            U       1.00      1.00      1.00         3
#            W       0.33      1.00      0.50         1
#            X       1.00      0.83      0.91         6
#            Y       0.67      0.40      0.50         5
#            Z       1.00      1.00      1.00         2
#
#     accuracy                           0.77        35
#    macro avg       0.77      0.86      0.77        35
# weighted avg       0.83      0.77      0.77        35
#
# Fold start on items 280 - 315
# Training Classifier...
#               precision    recall  f1-score   support
#
#            F       0.67      1.00      0.80         2
#            I       0.50      1.00      0.67         1
#            L       0.50      1.00      0.67         1
#            N       0.80      0.50      0.62         8
#            T       0.40      0.67      0.50         3
#            U       1.00      1.00      1.00         3
#            V       0.00      0.00      0.00         2
#            W       0.86      0.86      0.86         7
#            X       1.00      1.00      1.00         2
#            Y       0.67      1.00      0.80         2
#            Z       0.33      0.25      0.29         4
#
#     accuracy                           0.69        35
#    macro avg       0.61      0.75      0.65        35
# weighted avg       0.67      0.69      0.66        35
#
# Fold start on items 315 - 350
# Training Classifier...
#               precision    recall  f1-score   support
#
#            F       1.00      0.67      0.80         3
#            I       1.00      1.00      1.00         2
#            L       0.00      0.00      0.00         1
#            N       1.00      0.67      0.80         3
#            P       1.00      1.00      1.00         1
#            T       0.75      1.00      0.86         3
#            U       1.00      1.00      1.00         5
#            V       1.00      0.67      0.80         3
#            W       0.33      1.00      0.50         1
#            X       1.00      1.00      1.00         4
#            Y       1.00      0.50      0.67         2
#            Z       0.50      1.00      0.67         1
#
#     accuracy                           0.83        29
#    macro avg       0.80      0.79      0.76        29
# weighted avg       0.90      0.83      0.84        29
#
# (0.763595589960122, 0.6799014778325124, 0.6800262533435527)

# %%
#10-f cross_val on individual pairs (smaller datasets)
ind_results= {"r1" : (0.8224358974358974, 0.7846153846153846, 0.7778205128205128),
"r2" : (0.7678858784893269, 0.6637931034482759, 0.675242522256069),
"r3" : (0.8181915306915307, 0.7599067599067599, 0.758845497936407),
"r4" : (0.7992240687681375, 0.68470066518847, 0.6877442020358089),
"r5" : (0.7639380411255411, 0.6191666666666666, 0.6379182692307691),
"r6" : (0.9057487922705313, 0.8761528326745719, 0.8737389495294634),
"r7" : (0.8732662337662337, 0.8296739130434782, 0.8278420650668934),
"r8" : (0.7130039355485784, 0.5734432234432234, 0.5872288333290527)}

print("Trained on same data 10f cross (average performance per pair) av 1/8 of data")
print(np.mean([x[0] for x in ind_results.values()]))
print(np.mean([x[1] for x in ind_results.values()]))
print(np.mean([x[2] for x in ind_results.values()]))

print("*" * 30)
print("Trained on all data (mixed) 10-fold cross val (of random 1/8th of data)")
#10-f cross_val mixed overall (whole dataset)
global_result_10f_of_random_eighth = [
    (0.7303828289936665, 0.6563546798029556, 0.6591810707081643),
    (0.7773714129329894, 0.7020689655172414, 0.705385763114827),
    (0.7340298765274135, 0.6626600985221675, 0.6634152186073369),
    (0.763595589960122, 0.6799014778325124, 0.6800262533435527)
]
print(np.mean([x[0] for x in global_result_10f_of_random_eighth]))
print(np.mean([x[1] for x in global_result_10f_of_random_eighth]))
print(np.mean([x[2] for x in global_result_10f_of_random_eighth]))


print("*" * 30)
print("Trained on all data (mixed) 8-fold cross val (full_data)")
#10-f cross_val mixed overall (whole dataset)
global_result_8 = (0.7844808924585374, 0.7293746248177686, 0.7410059116896628)
global_result_10 = (0.7905361390798162, 0.7292899089488714, 0.7417777879399795)
for x in global_result_8:
    print(x)
    

print("*" * 30)
#mixed- trained on other 7
other_results= {"r1" : (0.7779836356055868, 0.6829268292682927, 0.690424865840207, None),
"r2" : (0.7219102027091829, 0.6401384083044983, 0.6505178871728421, None),
"r3" : (0.8292961148443981, 0.734375, 0.7530287500141206, None),
"r4" : (0.7893900944674533, 0.7048054919908466, 0.7258770742493045, None),
"r5" : (0.7215635412139649, 0.6059322033898306, 0.6263491634014793, None),
"r6" : (0.8328990107115107, 0.809375, 0.8035774233470034, None),
"r7" : (0.8375586804425542, 0.8149779735682819, 0.818528077822021, None),
"r8" : (0.7323545548007373, 0.5745098039215686, 0.5976834631543789, None)}

print("Trained on other data 8-dialogue-fold cross-val")
print(np.mean([x[0] for x in other_results.values()]))
print(np.mean([x[1] for x in other_results.values()]))
print(np.mean([x[2] for x in other_results.values()]))
# Out:
# Trained on same data 10f cross (average performance per pair) av 1/8 of data
# 0.8079617972619721
# 0.7239315686233538
# 0.728297606525622
# ******************************
# Trained on all data (mixed) 10-fold cross val (of random 1/8th of data)
# 0.7513449271035478
# 0.6752463054187192
# 0.6770020764434702
# ******************************
# Trained on all data (mixed) 8-fold cross val (full_data)
# 0.7844808924585374
# 0.7293746248177686
# 0.7410059116896628
# ******************************
# Trained on other data 8-dialogue-fold cross-val
# 0.7803694793494236
# 0.6958800888054149
# 0.7082483381251696

# %%
good_pieces = ["X", "Y", "P", "N", "U", "F", "Z", "L", "T", "I", "W", "V", "UNK"]
print("non standard pieces", {k:v for k,v in piece_counter.items() if k not in good_pieces})
piece_counter

# %%
print(len(word_counter), "words")
word_counter.most_common(20)
# Out:
# 374 words
# [('das', 94.59751915673368),
#  ('ja', 74.96806652002296),
#  ('rechts', 66.95496000139885),
#  ('unten', 65.01167651587855),
#  ('oben', 62.703650072015805),
#  ('links', 62.102001006203004),
#  ('richtig', 35.23788092527971),
#  ('okay', 30.58326592447299),
#  ('der', 26.705970444692667),
#  ('rote', 21.798976854347682),
#  ('gelbe', 21.03494271746558),
#  ('graue', 16.95892332641557),
#  ('blaue', 16.86355046913869),
#  ('grüne', 16.14851689160511),
#  ('kreuz', 15.95614052614051),
#  ('einzige', 15.723457520740121),
#  ('die', 15.714750797753208),
#  ('form', 15.108645811756922),
#  ('t', 14.205841142288502),
#  ('ähm', 12.765858277653606)]

# %%
word_total = sum(word_piece_counter.values())
piece_total= sum(piece_counter.values())

# %%
for piece, piece_count in piece_counter.items():
    p_piece = piece_count/piece_total
    print("piece:", piece, piece_count, p_piece)
    highest = -1
    best_word = ""
    rank = {}
    for word, w_count in word_counter.items():
        #print(word, w_count)
        if w_count < 2: 
            continue
        p_word = w_count / word_total
        p_word_piece = word_piece_counter[piece+"__"+word] / word_total
        #check bayes = p(w|c)p(c) = p(c|w)p(w)
        bayes_check_1 = (word_piece_counter[piece+"__"+word]/piece_count) * p_piece
        bayes_check_2 = (word_piece_counter[piece+"__"+word]/w_count) * p_word
        if not round(bayes_check_1,4)== round(bayes_check_2,4):
            print("MISMATCH", word, bayes_check_1, bayes_check_2)
        mi = (p_word_piece/(p_piece * p_word))
        rank[word] = (mi, word_piece_counter[piece+"__"+word], p_word_piece, w_count, p_word)
        if mi > highest:
            highest = mi
            best_word = word
    if True:
        top = 5
        for k, v in sorted(rank.items(), key=lambda x:x[1][0], reverse=True):
            print(k,v[0], [round(x,4) for x in v[1:]])
            top -=1
            if top <= 0: 
                break
    print("*" * 30)
# Out:
# piece: L 238 0.22995169082125605
# MISMATCH das 0.056392914653784244 0.05660905815529811
# MISMATCH l 0.02148148148148148 0.02156381598491366
# orangene 4.348739495798319 [4.3333, 0.0042, 4.3333, 0.0042]
# orange 4.217910991111246 [53.7333, 0.0521, 55.4, 0.0537]
# orangen 3.937511174682639 [9.575, 0.0093, 10.575, 0.0103]
# l-form 3.41686674669868 [1.8333, 0.0018, 2.3333, 0.0023]
# l 2.9507723740564398 [22.2333, 0.0216, 32.7667, 0.0318]
# ******************************
# piece: X 230 0.2222222222222222
# kreuz 4.5 [53.0, 0.0514, 53.0, 0.0514]
# roten 4.5 [5.6667, 0.0055, 5.6667, 0.0055]
# x 4.5 [2.8333, 0.0027, 2.8333, 0.0027]
# rot 4.5 [7.0, 0.0068, 7.0, 0.0068]
# rote 4.4639999999999995 [31.0, 0.0301, 31.25, 0.0303]
# ******************************
# piece: T 253 0.24444444444444444
# MISMATCH das 0.06937198067632855 0.0696378705120001
# MISMATCH grüne 0.022431561996779373 0.02251753798124791
# dunkelgrüne 4.090909090909091 [11.25, 0.0109, 11.25, 0.0109]
# t 3.8354691665949945 [66.0667, 0.0641, 70.4667, 0.0683]
# ts 3.6818181818181817 [3.0, 0.0029, 3.3333, 0.0032]
# grünen 2.400142230650706 [7.5, 0.0073, 12.7833, 0.0124]
# grün 1.8181818181818183 [4.0, 0.0039, 9.0, 0.0087]
# ******************************
# piece: U 201 0.19420289855072465
# brücke 5.149253731343284 [4.6667, 0.0045, 4.6667, 0.0045]
# u 5.149253731343284 [11.1667, 0.0108, 11.1667, 0.0108]
# gelben 5.149253731343284 [19.0333, 0.0185, 19.0333, 0.0185]
# gelb 5.149253731343284 [6.0, 0.0058, 6.0, 0.0058]
# gelbe 5.029224506836447 [34.9167, 0.0339, 35.75, 0.0347]
# ******************************
# piece: P 219 0.21159420289855072
# pinkfarbene 4.726027397260274 [5.1667, 0.005, 5.1667, 0.005]
# pink 4.726027397260274 [10.0, 0.0097, 10.0, 0.0097]
# pinken 4.726027397260274 [5.9524, 0.0058, 5.9524, 0.0058]
# rosanen 4.726027397260274 [5.0, 0.0048, 5.0, 0.0048]
# pinke 4.6572017555526 [33.8333, 0.0328, 34.3333, 0.0333]
# ******************************
# piece: I 195 0.18840579710144928
# MISMATCH lange 0.011465378421900166 0.011509323074406696
# balken 5.3076923076923075 [15.3333, 0.0149, 15.3333, 0.0149]
# lange 5.3076923076923075 [11.8667, 0.0115, 11.8667, 0.0115]
# strich 5.3076923076923075 [2.0833, 0.002, 2.0833, 0.002]
# dunkelblaue 5.3076923076923075 [2.1667, 0.0021, 2.1667, 0.0021]
# dunkelblauen 5.3076923076923075 [2.0, 0.0019, 2.0, 0.0019]
# ******************************
# piece: V 222 0.2144927536231884
# l-förmige 4.662162162162162 [2.6667, 0.0026, 2.6667, 0.0026]
# rechten 4.284149013878744 [2.8333, 0.0027, 3.0833, 0.003]
# winkel 4.197458933203022 [32.3667, 0.0314, 35.95, 0.0349]
# hellblaue 3.29093799682035 [4.0, 0.0039, 5.6667, 0.0055]
# blaue 1.7903497716331902 [24.45, 0.0237, 63.669, 0.0618]
# ******************************
# piece: Z 195 0.18840579710144928
# s 5.307692307692308 [3.0, 0.0029, 3.0, 0.0029]
# türkise 5.3076923076923075 [7.0, 0.0068, 7.0, 0.0068]
# türkis 5.3076923076923075 [2.0, 0.0019, 2.0, 0.0019]
# z 3.7245121337344713 [32.9357, 0.0319, 46.9357, 0.0455]
# andere 2.732229795520934 [2.0333, 0.002, 3.95, 0.0038]
# ******************************
# piece: W 250 0.24154589371980675
# MISMATCH grüne 0.030434782608695626 0.030551433441894146
# m 4.140000000000001 [21.3333, 0.0207, 21.3333, 0.0207]
# hellgrün 4.140000000000001 [4.0, 0.0039, 4.0, 0.0039]
# hellgrünen 4.140000000000001 [3.0, 0.0029, 3.0, 0.0029]
# hellgrüne 4.14 [10.0, 0.0097, 10.0, 0.0097]
# treppe 4.096113074204947 [11.6667, 0.0113, 11.7917, 0.0114]
# ******************************
# piece: Y 254 0.24541062801932367
# MISMATCH das 0.06347826086956525 0.06372156117880788
# braune 4.074803149606299 [44.2667, 0.0429, 44.2667, 0.0429]
# braun 4.074803149606299 [14.0, 0.0136, 14.0, 0.0136]
# braunen 4.074803149606299 [22.7, 0.022, 22.7, 0.022]
# sie 1.5280511811023623 [3.0, 0.0029, 8.0, 0.0078]
# eins 1.4058992767306793 [5.0833, 0.0049, 14.7333, 0.0143]
# ******************************
# piece: F 210 0.2028985507246377
# grau 4.928571428571428 [15.5, 0.015, 15.5, 0.015]
# grauen 4.928571428571428 [16.5, 0.016, 16.5, 0.016]
# 's 4.928571428571428 [2.0, 0.0019, 2.0, 0.0019]
# graue 4.807467290713753 [32.75, 0.0318, 33.575, 0.0326]
# gebilde 3.4120879120879124 [1.5, 0.0015, 2.1667, 0.0021]
# ******************************
# piece: N 276 0.26666666666666666
# MISMATCH lila 0.07439613526570042 0.07468128174685236
# lilanen 3.75 [6.0, 0.0058, 6.0, 0.0058]
# lilane 3.75 [12.3333, 0.012, 12.3333, 0.012]
# lila 3.682252922422955 [77.0, 0.0747, 78.4167, 0.0761]
# dieses? 1.25 [1.0, 0.001, 3.0, 0.0029]
# z 1.1185512098615127 [14.0, 0.0136, 46.9357, 0.0455]
# ******************************
# piece: W,T 2 0.001932367149758454
# grünen 23.614732724902215 [0.5833, 0.0006, 12.7833, 0.0124]
# die 10.076495132127956 [0.5833, 0.0006, 29.9583, 0.0291]
# das 0.0 [0, 0.0, 689.3119, 0.6686]
# orange 0.0 [0, 0.0, 55.4, 0.0537]
# l 0.0 [0, 0.0, 32.7667, 0.0318]
# ******************************
# piece: I,V,Z 2 0.001932367149758454
# das 0.0 [0, 0.0, 689.3119, 0.6686]
# orange 0.0 [0, 0.0, 55.4, 0.0537]
# l 0.0 [0, 0.0, 32.7667, 0.0318]
# kreuz 0.0 [0, 0.0, 53.0, 0.0514]
# es 0.0 [0, 0.0, 203.1667, 0.197]
# ******************************
# piece: UNK 1 0.000966183574879227
# das 1.501497352432196 [1.0, 0.001, 689.3119, 0.6686]
# orange 0.0 [0, 0.0, 55.4, 0.0537]
# l 0.0 [0, 0.0, 32.7667, 0.0318]
# kreuz 0.0 [0, 0.0, 53.0, 0.0514]
# es 0.0 [0, 0.0, 203.1667, 0.197]
# ******************************
# piece: V,T 1 0.000966183574879227
# blaue 8.127968288396083 [0.5, 0.0005, 63.669, 0.0618]
# der 6.667075658348795 [0.5, 0.0005, 77.6202, 0.0753]
# das 0.0 [0, 0.0, 689.3119, 0.6686]
# orange 0.0 [0, 0.0, 55.4, 0.0537]
# l 0.0 [0, 0.0, 32.7667, 0.0318]
# ******************************
# piece: P,T 1 0.000966183574879227
# diesen 156.42317380352642 [1.0, 0.001, 6.6167, 0.0064]
# das 0.0 [0, 0.0, 689.3119, 0.6686]
# orange 0.0 [0, 0.0, 55.4, 0.0537]
# l 0.0 [0, 0.0, 32.7667, 0.0318]
# kreuz 0.0 [0, 0.0, 53.0, 0.0514]
# ******************************
# piece: N,Z 1 0.000966183574879227
# die 11.515994436717666 [0.3333, 0.0003, 29.9583, 0.0291]
# das 0.0 [0, 0.0, 689.3119, 0.6686]
# orange 0.0 [0, 0.0, 55.4, 0.0537]
# l 0.0 [0, 0.0, 32.7667, 0.0318]
# kreuz 0.0 [0, 0.0, 53.0, 0.0514]
# ******************************
# piece: V,L 1 0.000966183574879227
# die 11.515994436717666 [0.3333, 0.0003, 29.9583, 0.0291]
# das 0.0 [0, 0.0, 689.3119, 0.6686]
# orange 0.0 [0, 0.0, 55.4, 0.0537]
# l 0.0 [0, 0.0, 32.7667, 0.0318]
# kreuz 0.0 [0, 0.0, 53.0, 0.0514]
# ******************************
# piece: T,Y 1 0.000966183574879227
# ts 103.49999999999999 [0.3333, 0.0003, 3.3333, 0.0032]
# die 11.515994436717666 [0.3333, 0.0003, 29.9583, 0.0291]
# das 0.0 [0, 0.0, 689.3119, 0.6686]
# orange 0.0 [0, 0.0, 55.4, 0.0537]
# l 0.0 [0, 0.0, 32.7667, 0.0318]
# ******************************

# %%
db.close()

# %%
"""
p(w, c) = p(w|c)p(c) = p(c|w)p(w)
p(w) is the liklihood of the word appearing in a referring expression
p(c) is the liklihood of a referring expression having this class
p(w|c) is the liklihood of a word appearing given we've got this class
p(c|w) is the liklihood of this class appearing given we've got this word
"""
# Out:
#   File "<ipython-input-106-dc7248c79cbb>", line 1
#     p(w, c) = p(w|c)p(c) = p(c|w)p(w)
#                     ^
# SyntaxError: invalid syntax
